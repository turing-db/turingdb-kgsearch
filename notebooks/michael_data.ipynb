# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>
#         Example notebook - AI governance control mappings
#     </h1>
#     <p>
#         Link to dataset : Michael Brock Li' dataset
#     </p>
# </div>

# %% [markdown]
# ## Executive Summary
#
# This notebook demonstrates a **knowledge graph-based approach** to managing regulatory control mappings across multiple standards (ISO42001, ISO27001, ISO27701, EU AI Act, NIST RMF, SOC2).
#
# **Key capabilities:**
# - **Semantic search**: Find relevant controls using natural language queries
# - **Cross-standard mapping**: Identify overlapping requirements between different frameworks
# - **Graph visualization**: Explore relationships between domains, topics, controls, and standards
# - **Hybrid search**: Combine semantic understanding with keyword matching for optimal results
#
# ---
#
# ## Data Overview
#
# **Dataset**: Michael Brock Li's AI governance control mappings
# - **44 control statements** covering AI governance requirements
# - **6 regulatory standards** with reference mappings
# - **Hierarchical structure**: Domain → Topic → Control → Standards
#
# ### Standard Coverage
# - ISO 42001 (AI Management System)
# - ISO 27001 (Information Security)
# - ISO 27701 (Privacy Information Management)
# - EU AI Act
# - NIST RMF (Risk Management Framework)
# - SOC 2 (Service Organization Control)

# %% [markdown]
# # Import modules and functions

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import re
import pandas as pd
import networkx as nx
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt
from IPython.display import display, Markdown

# %%
from turingdb_examples.utils import get_return_statements
from turingdb_examples.graph import build_create_command_from_networkx

# %%
from turingdb_graphrag.embeddings import (
    build_node_only_embeddings,
    build_context_enriched_embeddings,
    build_smart_enriched_embeddings,
    build_sparse_embeddings,
    build_node2vec_embeddings
)
from turingdb_graphrag.search import (
    dense_search,
    sparse_search,
    print_results,
    hybrid_search,
    print_hybrid_results,
    compare_search_methods
)
from turingdb_graphrag.subgraph import (
    get_subgraph_around_query
)
from turingdb_graphrag.visualization import (
    visualize_graph_with_pyvis,
    visualize_subgraph_interactive
)
from turingdb_graphrag.workflow import (
    search_and_expand_hybrid_filtered,
    generate_report_hybrid_workflow_results
)
from turingdb_graphrag.llm import (
    graph_to_llm_context,
    create_llm_prompt_with_graph,
    query_llm
)

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# # Set path to data

# %%
example_name = "AI_governance_control_mapping"
path_data = f"{os.getcwd()}/data/{example_name}"
if not os.path.exists(path_data):
    raise ValueError(f"{path_data} does not exists")

# %% [markdown]
# # Create graph using `turingdb` python package

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         See <a href="https://docs.turingdb.ai/quickstart">TuringDB Get started documentation</a> for the important steps to follow :
#     </h2>
#     <h3>
#         <ul>
#             <li>Create your TuringDB account</li>
#             <li>Create your instance in the <a href="https://console.turingdb.ai/auth">TuringDB Cloud UI</a></li>
#             <li>Copy your Instance ID from the Database Instances management page</li>
#             <li>Get API Key from the Settings in UI</li>
#         </ul>
#         Remember to have your instance active while working in this notebook !
#     </h3>
# </div>

# %% [markdown]
# ## Connect to instance and transfer data

# %%
from turingdb import TuringDB

# Create TuringDB client
client = TuringDB(
    host="http://localhost:6666"  # Remove this parameter and set the two parameters below
    # instance_id=os.getenv("INSTANCE_ID"),
    # auth_token=os.getenv("AUTH_TOKEN"),
)

# %%
# %%time

# TODO: Jira ticket
# - when access_key and secret_key and not correct, no error shown
# - why 6s the first time and 2s after ?
client.s3_connect(
    bucket_name="turing-internal",
    region="eu-west-2",
    access_key=os.getenv("AWS_ACCESS_KEY"),
    secret_key=os.getenv("AWS_SECRET_KEY")
)
# Out:
# CPU times: user 93.5 ms, sys: 43 ms, total: 136 ms
# Wall time: 2.19 s

# %%
! tree -L 2 /home/dev/.turing/
# Out:
# /home/dev/.turing/
# ├── data
# │   ├── ai_gov_control_mappings_full.csv
# │   └── reactome.dump
# └── graphs
#     ├── AI_governance_control_mapping1
#     ├── AI_governance_control_mapping2
#     ├── AI_governance_control_mapping3
#     ├── AI_governance_control_mapping4
#     ├── AI_governance_control_mapping5
#     ├── AI_governance_control_mapping6
#     ├── default
#     └── reactome
#
# 10 directories, 2 files

# %%
# %%time

client.transfer(
    src="data/AI_governance_control_mapping/ai_gov_control_mappings_full.csv",
    dst="turingdb://ai_gov_control_mappings_full.csv"  # to s3 bucket or TuringDB instance or local .turing
)
# Out:
# CPU times: user 75.1 ms, sys: 12.9 ms, total: 88 ms
# Wall time: 374 ms

# %%
! tree -L 2 /home/dev/.turing/
# Out:
# /home/dev/.turing/
# ├── data
# │   ├── ai_gov_control_mappings_full.csv
# │   └── reactome.dump
# └── graphs
#     ├── AI_governance_control_mapping1
#     ├── AI_governance_control_mapping2
#     ├── AI_governance_control_mapping3
#     ├── AI_governance_control_mapping4
#     ├── AI_governance_control_mapping5
#     ├── AI_governance_control_mapping6
#     ├── default
#     └── reactome
#
# 10 directories, 2 files

# %% [markdown]
# ## Check data files are available

# %%
list_csv_files = sorted(os.listdir(path_data))
if not "ai_gov_control_mappings_full.csv" in list_csv_files:
    raise ValueError(f"csv file is not available in {path_data}")

# %% [markdown]
# ## Import and format data

# %%
# Load CSV
path_turing_folder = f"{os.getenv('HOME')}/.turing"
df = pd.read_csv(f"{path_turing_folder}/data/ai_gov_control_mappings_full.csv")
df = df.replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r'\n',  ' ', regex=True)
print(f"✓ Loaded {len(df)} rows from CSV")
df
# Out:
# ✓ Loaded 44 rows from CSV
#                               Domain Master  \
# 0            Governance & Leadership   GL-1
# 1            Governance & Leadership   GL-2
# 2            Governance & Leadership   GL-3
# 3                    Risk Management   RM-1
# 4                    Risk Management   RM-2
# 5                    Risk Management   RM-3
# 6                    Risk Management   RM-4
# 7              Regulatory Operations   RO-1
# 8              Regulatory Operations   RO-2
# 9              Regulatory Operations   RO-3
# 10             Regulatory Operations   RO-4
# 11  System, Data and Model Lifecycle   LC-1
# 12  System, Data and Model Lifecycle   LC-2
# 13  System, Data and Model Lifecycle   LC-3
# 14  System, Data and Model Lifecycle   LC-4
# 15  System, Data and Model Lifecycle   LC-5
# 16                          Security   SE-1
# 17                          Security   SE-2
# 18                          Security   SE-3
# 19                          Security   SE-4
# 20                          Security   SE-5
# 21                          Security   SE-6
# 22               Safe Responsible AI   RS-1
# 23               Safe Responsible AI   RS-2
# 24               Safe Responsible AI   RS-3
# 25               Safe Responsible AI   RS-4
# 26               Safe Responsible AI   RS-5
# 27                           Privacy   PR-1
# 28                           Privacy   PR-2
# 29                           Privacy   PR-3
# 30                           Privacy   PR-4
# 31               Assurance and Audit   AA-1
# 32               Assurance and Audit   AA-2
# 33               Assurance and Audit   AA-3
# 34            Operational Monitoring   OM-1
# 35            Operational Monitoring   OM-2
# 36            Operational Monitoring   OM-3
# 37        Third Party & Supply Chain   TP-1
# 38        Third Party & Supply Chain   TP-2
# 39      Transparency & Communication   CO-1
# 40      Transparency & Communication   CO-2
# 41               Incident Management   IM-1
# 42               Incident Management   IM-2
# 43               Incident Management   IM-3
#
#                                                 Topic  \
# 0             Executive Commitment and Accountability
# 1                 Roles, Responsibilities & Resources
# 2                    Strategic Alignment & Objectives
# 3            Risk Management Framework and Governance
# 4           Risk Identification and Impact Assessment
# 5           Risk Treatment and Control Implementation
# 6                        Risk Monitoring and Response
# 7                     Regulatory Compliance Framework
# 8              Transparency, Disclosure and Reporting
# 9                                      Record-Keeping
# 10                             Post-Market Monitoring
# 11                        Data Quality and Governance
# 12        System Development and Lifecycle Management
# 13             Resource Management and Infrastructure
# 14                            Technical Documentation
# 15                Change Management & Version Control
# 16  Security Governance, Architecture and Engineering
# 17                       Identity & Access Management
# 18                                  Software Security
# 19                                      Data Security
# 20                                   Network Security
# 21                                  Physical Security
# 22                   Human Oversight and Intervention
# 23                                             Safety
# 24                                         Robustness
# 25                Explainability and Interpretability
# 26                       Fairness and Bias Management
# 27                   Privacy by Design and Governance
# 28                           Personal Data Management
# 29                  Privacy Compliance and Monitoring
# 30      Privacy-Enhancing Technologies and Mechanisms
# 31                        Internal Assessment & Audit
# 32           Independent Assessment and Certification
# 33                     Safety and Security Validation
# 34                      System Performance Monitoring
# 35                                      Event Logging
# 36                             Continuous Improvement
# 37              Third-Party Provider Responsibilities
# 38                           Supplier Risk Management
# 39                             AI System Transparency
# 40                Stakeholder Engagement and Feedback
# 41                    Incident Detection and Response
# 42                Incident Reporting and Notification
# 43                  Incident Analysis and Improvement
#
#                                     Control Statement  \
# 0   The organisation's executive leadership shall ...
# 1   The organisation shall define, document, and m...
# 2   The organisation shall document clear objectiv...
# 3   The organisation shall establish, document, an...
# 4   The organisation shall conduct and document co...
# 5   The organisation shall implement appropriate t...
# 6   The organisation shall implement continuous mo...
# 7   The organisation shall establish, document, an...
# 8   The organisation shall implement mechanisms to...
# 9   The organisation shall maintain comprehensive ...
# 10  The organisation shall implement comprehensive...
# 11  The organisation shall establish and maintain ...
# 12  The organisation shall define, document, and m...
# 13  The organisation shall document and maintain i...
# 14  The organisation shall maintain comprehensive ...
# 15  The organisation shall establish and maintain ...
# 16  The organisation shall establish and maintain ...
# 17  The organisation shall implement and maintains...
# 18  The organisation shall ensure all software dev...
# 19  The organisation shall protect data throughout...
# 20  The organisation shall implement and maintain ...
# 21  The organisation shall implement and maintain ...
# 22  The organisation shall implement mechanisms fo...
# 23  The organisation shall establish and maintain ...
# 24  The organisation shall ensure AI systems demon...
# 25  The organisation shall ensure AI systems' deci...
# 26  The organisation shall implement processes to ...
# 27  The organisation shall implement privacy by de...
# 28  The organisation shall implement operational p...
# 29  The organisation shall establish processes to ...
# 30  The organisation shall implement appropriate t...
# 31  The organisation shall establish and maintain ...
# 32  The organisation shall ensure regular independ...
# 33  The organisation shall conduct regular testing...
# 34  The organisation shall implement continuous mo...
# 35  The organisation shall maintain comprehensive ...
# 36  The organisation shall establish and maintain ...
# 37  The organisation shall establish clear account...
# 38  The organisation shall implement comprehensive...
# 39  The organisation shall ensure AI systems are d...
# 40  The organisation shall implement comprehensive...
# 41  The organisation shall establish and maintain ...
# 42  The organisation shall implement processes for...
# 43  The organisation shall analyse incidents to id...
#
#                                              ISO42001  \
# 0                   4.1 5.1 5.2 9.3 A.2.2 A.2.3 A.2.4
# 1                             5.3 7.1-7.3 A.3.2 A.4.2
# 2   4.1-4.4 5.2 6.2-6.3 A.2.2-A.2.4 A.6.1.2 A.9.3 ...
# 3                                                 6.1
# 4       6.1.1-6.1.2 6.1.4 8.4 A.5.2 A.5.3 A.5.4 A.5.5
# 5                                               6.1.3
# 6                                       6.1.3 8.1-8.3
# 7                                                 NaN
# 8                                         A.8.3 A.8.5
# 9                                                 NaN
# 10                                              A.8.3
# 11                                        A.7.2-A.7.6
# 12            A.6.1.2-A.6.1.3 A.6.2.2-A.6.2.3 A.6.2.5
# 13                           A.4.3 A.4.5 A.4.6 A.10.2
# 14                        7.5.1-7.5.3 A.6.2.7 A.6.2.8
# 15                                            A.6.2.5
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                  A.9.2 A.9.3 A.9.4
# 23                            A.5.2 A.5.3 A.5.4 A.5.5
# 24                                              A.9.4
# 25                                              A.5.3
# 26                                              A.5.4
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                9.1 9.2 9.3 A.6.2.4
# 32                                  9.1 9.3 10.1 10.2
# 33                                            9.1 9.3
# 34                                    8.1-8.3 A.6.2.6
# 35                                            A.6.2.8
# 36                               9.1 10.1 10.2 A.10.4
# 37                                             A.10.2
# 38                                             A.10.3
# 39                      7.4 A.6.2.7 A.8.2 A.9.3 A.9.4
# 40                           A.3.3 A.8.3 A.8.5 A.10.4
# 41                                              A.8.4
# 42                                              A.8.4
# 43                                              A.8.4
#
#                                              ISO27001  \
# 0                             5.1 5.2 9.3 A.5.1 A.5.2
# 1                       5.3 7.1-7.3 A.6.1 A.6.2 A.7.2
# 2                                     4.1-4.4 6.2-6.3
# 3                                                 6.1
# 4                                               6.1.2
# 5                                               6.1.3
# 6                                       6.1.3 8.1-8.3
# 7                                              A.18.1
# 8                                               A.6.3
# 9                                               A.7.2
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                        A.8.1 A.8.2
# 14                                        7.5.1-7.5.3
# 15                                             A.12.2
# 16  A.5.1-A.5.2 A.6.1-A.6.2 A.6.5 A.7.1-A.7.4 A.12...
# 17                            A.9.1 A.9.2 A.9.3 A.9.4
# 18                               A.14.1 A.14.2 A.12.2
# 19     A.8.1-A.8.7 A.10.1 A.10.2 A.12.4 A.12.5 A.14.3
# 20          A.13.1-A.13.3 A.12.4 A.12.6 A.10.1 A.10.2
# 21                 A.11.1 A.11.2 A.11.3 A.11.4 A.11.5
# 22                     A.18.1.1  A.18.2.2 A.6.1 A.6.2
# 23                                             A.12.1
# 24                                      A.17.1 A.17.2
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                 9.1 9.2 9.3 A.18.2
# 32                    9.1 9.3 10.1 10.2 A.18.1 A.18.2
# 33                              9.1 9.3 A.18.1 A.18.2
# 34                8.1-8.3 A.12.3 A.12.6 A.17.1 A.17.2
# 35                                      A.12.6 A.12.7
# 36          9.1 10.1 10.2 A.18.2 A.15.2 A.12.6 A.18.1
# 37                                             A.15.1
# 38                                      A.15.1 A.15.2
# 39                                          7.4 A.6.4
# 40                                          4.2 A.6.4
# 41                                      A.16.1 A.12.7
# 42                                      A.16.1 A.16.2
# 43                                             A.16.3
#
#                                              ISO27701  \
# 0                                         6.1.1 6.1.2
# 1                             6.2.1 6.2.2 7.2.2 9.2.3
# 2                             A.7.2.1 A.7.2.2 B.8.2.2
# 3                      12.2.1 A.7.2.5 A.7.2.8 B.8.2.6
# 4                            A.7.2.5 A.7.3.10 A.7.4.4
# 5                     A.7.4.1 A.7.4.2 A.7.4.4 A.7.4.5
# 6             A.7.4.3 A.7.4.9 B.8.2.4 B.8.2.5 B.8.4.3
# 7   18.2.1 A.7.2.1-A.7.2.4 B.8.2.1-B.8.2.2 B.8.2.4...
# 8   6.2.3 A.7.3.2-A.7.3.3 A.7.3.8-A.7.3.9 A.7.5.3-...
# 9   8.2.3 A.7.2.8 A.7.3.1 A.7.4.3 A.7.4.6-A.7.4.8 ...
# 10  6.2.3 A.7.3.6-A.7.3.7 A.7.3.10 A.7.4.3 B.8.3.1...
# 11    A.7.4.1-A.7.4.2 A.7.4.6-A.7.4.8 B.8.4.1-B.8.4.2
# 12    A.7.4.1-A.7.4.2 A.7.4.5-A.7.4.8 B.8.4.1-B.8.4.2
# 13                            A.7.2.6 A.7.2.7 B.8.5.6
# 14            A.7.2.8 A.7.5.3 A.7.5.4 B.8.2.6 B.8.5.3
# 15                            A.7.3.7 B.8.5.7 B.8.5.8
# 16                                      14.2.1 14.2.2
# 17                                  9.2.1 9.2.2 9.2.4
# 18                                      14.2.1 14.2.2
# 19       8.2.4 8.3.1 8.3.2 8.3.3 10.2.1 10.2.2 11.2.2
# 20                                             13.2.1
# 21                                             11.2.1
# 22                                        7.2.2 7.2.5
# 23                                        7.2.3 7.2.4
# 24                                              7.2.8
# 25                                              7.2.1
# 26                                              7.2.6
# 27  6.1.1 6.1.2 6.2.1-6.2.4 7.2.1-7.2.3 7.2.5 7.2....
# 28  8.2.1-8.2.4  8.3.1-8.3.3 A.7.2.1-A.7.2.8 A.7.3...
# 29  12.2.2 15.2.1 16.2.1 16.2.2 17.2.1 18.2.1 18.2...
# 30  9.2.1-9.2.4 10.2.1-10.2.2 11.2.1-11.2.2 13.2.1...
# 31                       8.2.3 18.2.2 A.7.2.5 A.7.4.3
# 32                                              7.2.1
# 33                                              7.2.5
# 34                                     12.2.2 A.7.4.3
# 35                                             12.2.2
# 36                                    A.7.4.3 A.7.3.6
# 37             15.2.1 A.7.2.6-A.7.2.7 B.8.5.6-B.8.5.8
# 38     15.2.1 A.7.2.6 A.7.5.1-A.7.5.2 B.8.5.1-B.8.5.2
# 39                   A.7.3.2 A.7.3.3 A.7.3.10 B.8.2.3
# 40                            A.7.3.4 A.7.3.5 A.7.3.9
# 41                             16.2.1 A.7.3.7 B.8.5.4
# 42                             16.2.2 B.8.5.4 B.8.5.5
# 43                                             16.2.1
#
#                                             EU AI ACT  \
# 0                                                 4.1
# 1                                      22.1 22.2 26.3
# 2                                                 NaN
# 3                                             9.1 9.2
# 4                                            9.9 27.1
# 5                            8.1 8.2 17.1 9.3 9.4 9.5
# 6                                                 9.6
# 7   5.1 5.2 6.1-6.4 8.1-8.2 40.1 41.1 42.1 43.1-43...
# 8             50.1-50.5 86.1-86.3 20.1 20.2 60.7 60.8
# 9                  11.1 11.3 18.1 19.1 19.2 71.2 71.3
# 10                           72.1-72.4 79.4 80.4-80.5
# 11                                          10.1-10.6
# 12                                                NaN
# 13                                                NaN
# 14                           11.1-11.3 12.1-12.3 18.1
# 15                                               11.3
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                 14.1-14.5 26.2 4.1
# 23                                    5.1 5.2 9.1-9.3
# 24                             8.1 8.2 15.1 15.4 15.5
# 25                                50.2 50.3 50.4 50.5
# 26                                           5.1 26.4
# 27                                     10.5 26.9 27.4
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31              9.7-9.8 17.1-17.2 60.1-60.9 61.1 61.2
# 32            20.1 22.3-22.4 40.1 43.1-43.4 44.2 44.3
# 33                                41.1-41.2 42.1-42.2
# 34                           26.5 72.1 72.2 72.3 72.4
# 35                     12.1-12.3 19.1-19.2  21.2 26.6
# 36                           17.1 72.1 72.2 72.3 72.4
# 37                               25.1  25.2 25.3 25.4
# 38                                               25.4
# 39                 13.1-13.3 15.3 50.1-50.5 86.1-86.3
# 40                                     4.1 26.7 26.11
# 41                                               73.6
# 42                               73.1-73.5 73.9 73.10
# 43                                               73.6
#
#                                              NIST RMF  \
# 0                    Govern 1.1 Govern 2.3 Govern 3.1
# 1                                                 NaN
# 2   Map 1.3 Map 1.4 Govern 1.1 Govern 1.2 Govern 4...
# 3            Govern 1.3 Govern 1.4 Govern 1.5 Map 1.5
# 4   Map 1.1  Map 3.1 Map 3.2 Measure 2.6 Measure 2...
# 5                    Manage 1.2 Manage 1.3 Manage 1.4
# 6   Measure 3.1 Measure 3.2 Manage 2.1 Manage 2.2 ...
# 7                                  Govern 1.1 Map 4.1
# 8                                  Govern 6.1 Map 4.1
# 9                                Map 4.1 Measure 2.12
# 10                            Govern 6.1 Measure 2.12
# 11                                            Map 2.1
# 12                                 Map 1.6 Govern 1.7
# 13                                         Govern 1.6
# 14                                    Map 2.2 Map 3.3
# 15                                            Map 2.1
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                         Govern 3.2 Map 3.4 Map 3.5
# 23    Map 1.1 Map 3.1 Map 3.2 Measure 3.1 Measure 3.2
# 24            Map 2.1 Map 2.2 Measure 4.2 Measure 4.3
# 25             Govern 4.2 Map 2.2 Map 2.3 Measure 2.8
# 26              Measure 2.11  Govern 5.2  Measure 2.2
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31     Map 2.3  Measure 2.1  Measure 2.3  Measure 2.5
# 32               Measure 1.3  Measure 4.2  Govern 4.3
# 33                           Measure 2.6  Measure 2.7
# 34      Measure 1.2 Measure 2.4 Manage 2.2 Manage 2.4
# 35                                         Govern 4.3
# 36                              Manage 4.1 Manage 4.2
# 37                                Map 4.1  Govern 6.1
# 38        Govern 5.1 Manage 3.1 Govern 6.1 Govern 6.2
# 39                                Map 1.2 Measure 4.1
# 40  Govern 5.1 Govern 5.2 Map 5.2 Measure 3.3 Meas...
# 41                                         Manage 4.3
# 42                                         Manage 4.3
# 43                                         Manage 4.3
#
#                                          SOC2
# 0   CC.1.1 CC.1.2 CC.1.3 CC.1.4 CC.1.5 CC.5.3
# 1                               CC.1.3 CC.1.4
# 2                                         NaN
# 3                                       CC3.1
# 4                                       CC3.2
# 5                                CC5.1  CC9.1
# 6                                 CC3.4 CC9.2
# 7                                       CC1.5
# 8                        CC2.3 P1.1 P1.2 P1.3
# 9                              P3.1 P3.2 P3.3
# 10                                      CC1.5
# 11                                        NaN
# 12                                CC8.1 CC8.2
# 13                                        NaN
# 14                                        NaN
# 15                                CC8.1 CC8.2
# 16  CC2.3 CC3.1 CC3.2 CC5.2 CC7.2 CC7.3 CC9.3
# 17                          CC6.1 CC6.2 CC6.3
# 18                                CC5.2 CC7.1
# 19       CC6.4-CC6.7 C1.1 C1.2 P5.1-P5.4 P5.6
# 20                          CC6.6 CC7.1 CC7.2
# 21                                      CC6.1
# 22                               CC1.1  CC2.1
# 23                                CC4.1 CC5.1
# 24                                CC7.1 CC8.1
# 25                                CC2.2 CC2.3
# 26                                CC1.3 CC5.3
# 27                             P1.1 P1.2 P1.3
# 28              P2.1 P2.2 P3.1-P3.3 P4.1-P4.3
# 29                   P6.1 P6.2 P6.3 P6.4 P6.5
# 30              P5.1 P5.2 P5.3 P5.4 P5.5 P5.6
# 31                          PI1.1 PI1.2 CC4.1
# 32                                CC4.2 CC3.1
# 33                                      CC7.1
# 34                      CC4.1 CC4.2 A1.1 A1.2
# 35                                CC7.2 CC7.3
# 36                                 CC3.3 A1.3
# 37                                      CC2.3
# 38                                      CC9.2
# 39                                      CC2.2
# 40                                      CC2.2
# 41                            CC7.4 P6.1 P6.2
# 42                                  P6.3 P6.4
# 43                                       P6.5

# %% [markdown]
# ## Create graph + Graph Design - Regulatory Control Mappings
#
# ### Graph Structure
#
# ```
# [Domain] --contains--> [Topic] --has_control--> [Control] --maps_to--> [Standard Reference]
# ```
#
# **Example:**
# ```
# Data Governance → Privacy → "Ensure data encryption" → ISO27001: A.8.24
#                                                       → NIST RMF: SC-28
# ```
#
# ### Node Types
#
# | Type | Count | Description | Searchable |
# |------|-------|-------------|------------|
# | **Control** | 44 | Actual control statements | ✅ Primary |
# | **Topic** | ~15-20 | Sub-categories | ✅ Optional |
# | **Domain** | ~5-10 | High-level groupings | ✅ Optional |
# | **Standard** | ~50-100 | Standard references | ❌ Reference only |
#
# ### Design Benefits
#
# 1. **Flexible querying**: Search by meaning, not just keywords
# 2. **Many-to-many mappings**: One control can satisfy multiple standards
# 3. **Hierarchical navigation**: Browse from high-level domains down to specific requirements
# 4. **Cross-standard analysis**: Find overlaps and gaps between frameworks
# 5. **Supports Key Queries**:
#    - "Find controls about data privacy" (semantic search)
#    - "Which standards cover this topic?" (graph traversal)
#    - "What's the overlap between ISO and NIST?" (cross-standard analysis)

# %%
# Create graph
G = nx.DiGraph()

# Build graph structure
for idx, row in df.iterrows():
    # Main control node (what we'll search)
    control_id = f"control_{idx}"
    G.add_node(control_id, 
               type='control',
               statement=row['Control Statement'],
               domain=row['Domain'],
               master=row['Master'],
               topic=row['Topic'])
    
    # Domain node
    domain_id = f"domain_{row['Domain']}"
    if domain_id not in G:
        G.add_node(domain_id, type='domain', name=row['Domain'])
    
    # Topic node
    topic_id = f"topic_{row['Topic']}"
    if topic_id not in G:
        G.add_node(topic_id, type='topic', name=row['Topic'])
    
    # Connections
    G.add_edge(domain_id, topic_id, rel='contains')
    G.add_edge(topic_id, control_id, rel='has_control')
    
    # Standard mappings
    standards = {
        'ISO42001': row['ISO42001'],
        'ISO27001': row['ISO27001'],
        'ISO27701': row['ISO27701'],
        'EU_AI_ACT': row['EU AI ACT'],
        'NIST_RMF': row['NIST RMF'],
        'SOC2': row['SOC2']
    }
    
    for std_name, std_ref in standards.items():
        if pd.notna(std_ref) and str(std_ref).strip():
            std_id = f"std_{std_name}_{std_ref}"
            if std_id not in G:
                G.add_node(std_id, type='standard', standard=std_name, reference=std_ref)
            G.add_edge(control_id, std_id, rel='maps_to')

print(f"✓ Graph built: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")

# Show breakdown
node_types = {}
for node, data in G.nodes(data=True):
    node_type = data.get('type', 'unknown')
    node_types[node_type] = node_types.get(node_type, 0) + 1

print("\nNode breakdown:")
for ntype, count in node_types.items():
    print(f"  {ntype}: {count}")
# Out:
# ✓ Graph built: 305 nodes, 304 edges
#
# Node breakdown:
#   control: 44
#   domain: 12
#   topic: 44
#   standard: 205

# %% [markdown]
# ## Create `turingdb` graph

# %%
# Get list of available graphs
list_graphs = client.query("LIST GRAPH").loc[:, 0].tolist()

# %%
# Set graph name
graph_name_prefix = example_name
graph_name_nb_suffix = str(
    max(
        [
            int(re.sub(graph_name_prefix, "", g))
            for g in list_graphs
            if g.startswith(graph_name_prefix)
            and re.sub(graph_name_prefix, "", g).isdigit()
        ]
        + [0]
    )
    + 1
)
graph_name = graph_name_prefix + graph_name_nb_suffix
graph_name = re.sub("-", "_", graph_name)
graph_name
# Out:
# 'AI_governance_control_mapping7'

# %%
# %%time

# Set graph
client.query(f"CREATE GRAPH {graph_name}")
client.set_graph(graph_name)

# Create a new change on the graph
change = client.query("CHANGE NEW").loc[0, 0]
#TODO change to : client.new_change()
print(f"Current change {change}")

# Checkout into the change
client.checkout(change=change)
# Out:
# Current change 0
# CPU times: user 1.12 ms, sys: 872 μs, total: 1.99 ms
# Wall time: 11.4 ms

# %%
# Build CREATE command from networkx object
create_command = build_create_command_from_networkx(G)
print(f"Cypher CREATE command :\n\n{100 * '*'}\n{create_command}\n{100 * '*'}")
# Out:
# Cypher CREATE command :
#
# ****************************************************************************************************
# CREATE (n0:Control {"id":"control_0", "type":"control", "statement":"The organisation s executive leadership shall establish, document, and maintain formal accountability for AI governance through approved policies that align with organisational objectives and values. These policies shall be reviewed at planned intervals by executive leadership to ensure continued effectiveness and relevance. Executive leadership shall demonstrate active engagement in AI risk decisions and maintain ultimate accountability for the organisation s AI systems.", "domain":"Governance & Leadership", "master":"GL-1", "topic":"Executive Commitment and Accountability"}),
# (n1:Domain {"id":"domain_Governance & Leadership", "type":"domain", "name":"Governance & Leadership"}),
# (n2:Topic {"id":"topic_Executive Commitment and Accountability", "type":"topic", "name":"Executive Commitment and Accountability"}),
# (n3:Standard {"id":"std_ISO42001_4.1 5.1 5.2 9.3 A.2.2 A.2.3 A.2.4", "type":"standard", "standard":"ISO42001", "reference":"4.1 5.1 5.2 9.3 A.2.2 A.2.3 A.2.4"}),
# (n4:Standard {"id":"std_ISO27001_5.1 5.2 9.3 A.5.1 A.5.2", "type":"standard", "standard":"ISO27001", "reference":"5.1 5.2 9.3 A.5.1 A.5.2"}),
# (n5:Standard {"id":"std_ISO27701_6.1.1 6.1.2", "type":"standard", "standard":"ISO27701", "reference":"6.1.1 6.1.2"}),
# (n6:Standard {"id":"std_EU_AI_ACT_4.1", "type":"standard", "standard":"EU_AI_ACT", "reference":"4.1"}),
# (n7:Standard {"id":"std_NIST_RMF_Govern 1.1 Govern 2.3 Govern 3.1", "type":"standard", "standard":"NIST_RMF", "reference":"Govern 1.1 Govern 2.3 Govern 3.1"}),
# (n8:Standard {"id":"std_SOC2_CC.1.1 CC.1.2 CC.1.3 CC.1.4 CC.1.5 CC.5.3", "type":"standard", "standard":"SOC2", "reference":"CC.1.1 CC.1.2 CC.1.3 CC.1.4 CC.1.5 CC.5.3"}),
# (n9:Control {"id":"control_1", "type":"control", "statement":"The organisation shall define, document, and maintain clear roles and responsibilities for AI governance, ensuring appropriate segregation of duties and allocation of resources. These roles shall be staffed with competent individuals who understand their responsibilities for AI system development, deployment, and oversight. The organisation shall maintain documentation of required resources, including personnel competencies, tools, and infrastructure needed for effective AI governance.", "domain":"Governance & Leadership", "master":"GL-2", "topic":"Roles, Responsibilities & Resources"}),
# (n10:Topic {"id":"topic_Roles, Responsibilities & Resources", "type":"topic", "name":"Roles, Responsibilities & Resources"}),
# (n11:Standard {"id":"std_ISO42001_5.3 7.1-7.3 A.3.2 A.4.2", "type":"standard", "standard":"ISO42001", "reference":"5.3 7.1-7.3 A.3.2 A.4.2"}),
# (n12:Standard {"id":"std_ISO27001_5.3 7.1-7.3 A.6.1 A.6.2 A.7.2", "type":"standard", "standard":"ISO27001", "reference":"5.3 7.1-7.3 A.6.1 A.6.2 A.7.2"}),
# (n13:Standard {"id":"std_ISO27701_6.2.1 6.2.2 7.2.2 9.2.3", "type":"standard", "standard":"ISO27701", "reference":"6.2.1 6.2.2 7.2.2 9.2.3"}),
# (n14:Standard {"id":"std_EU_AI_ACT_22.1 22.2 26.3", "type":"standard", "standard":"EU_AI_ACT", "reference":"22.1 22.2 26.3"}),
# (n15:Standard {"id":"std_SOC2_CC.1.3 CC.1.4", "type":"standard", "standard":"SOC2", "reference":"CC.1.3 CC.1.4"}),
# (n16:Control {"id":"control_2", "type":"control", "statement":"The organisation shall document clear objectives for the responsible development and use of AI systems, ensuring alignment between business goals, ethical principles, and regulatory requirements. These objectives shall be integrated into organisational practices and regularly reviewed to maintain effectiveness. The organisation shall foster an environment that promotes critical thinking and safety-first approaches to AI development and deployment.", "domain":"Governance & Leadership", "master":"GL-3", "topic":"Strategic Alignment & Objectives"}),
# (n17:Topic {"id":"topic_Strategic Alignment & Objectives", "type":"topic", "name":"Strategic Alignment & Objectives"}),
# (n18:Standard {"id":"std_ISO42001_4.1-4.4 5.2 6.2-6.3 A.2.2-A.2.4 A.6.1.2 A.9.3 A.9.4", "type":"standard", "standard":"ISO42001", "reference":"4.1-4.4 5.2 6.2-6.3 A.2.2-A.2.4 A.6.1.2 A.9.3 A.9.4"}),
# (n19:Standard {"id":"std_ISO27001_4.1-4.4 6.2-6.3", "type":"standard", "standard":"ISO27001", "reference":"4.1-4.4 6.2-6.3"}),
# (n20:Standard {"id":"std_ISO27701_A.7.2.1 A.7.2.2 B.8.2.2", "type":"standard", "standard":"ISO27701", "reference":"A.7.2.1 A.7.2.2 B.8.2.2"}),
# (n21:Standard {"id":"std_NIST_RMF_Map 1.3 Map 1.4 Govern 1.1 Govern 1.2 Govern 4.1 Govern 3.1", "type":"standard", "standard":"NIST_RMF", "reference":"Map 1.3 Map 1.4 Govern 1.1 Govern 1.2 Govern 4.1 Govern 3.1"}),
# (n22:Control {"id":"control_3", "type":"control", "statement":"The organisation shall establish, document, and maintain a comprehensive risk management system covering the entire AI lifecycle. This system shall define clear roles, responsibilities, and processes for identifying, assessing, treating, and monitoring AI-related risks. The framework shall incorporate regular reviews by executive leadership and ensure risk management activities align with organisational risk tolerance. Risk management processes shall be transparent, documented, and appropriately resourced to maintain effectiveness.", "domain":"Risk Management", "master":"RM-1", "topic":"Risk Management Framework and Governance"}),
# (n23:Domain {"id":"domain_Risk Management", "type":"domain", "name":"Risk Management"}),
# (n24:Topic {"id":"topic_Risk Management Framework and Governance", "type":"topic", "name":"Risk Management Framework and Governance"}),
# (n25:Standard {"id":"std_ISO42001_6.1", "type":"standard", "standard":"ISO42001", "reference":"6.1"}),
# (n26:Standard {"id":"std_ISO27001_6.1", "type":"standard", "standard":"ISO27001", "reference":"6.1"}),
# (n27:Standard {"id":"std_ISO27701_12.2.1 A.7.2.5 A.7.2.8 B.8.2.6", "type":"standard", "standard":"ISO27701", "reference":"12.2.1 A.7.2.5 A.7.2.8 B.8.2.6"}),
# (n28:Standard {"id":"std_EU_AI_ACT_9.1 9.2", "type":"standard", "standard":"EU_AI_ACT", "reference":"9.1 9.2"}),
# (n29:Standard {"id":"std_NIST_RMF_Govern 1.3 Govern 1.4 Govern 1.5 Map 1.5", "type":"standard", "standard":"NIST_RMF", "reference":"Govern 1.3 Govern 1.4 Govern 1.5 Map 1.5"}),
# (n30:Standard {"id":"std_SOC2_CC3.1", "type":"standard", "standard":"SOC2", "reference":"CC3.1"}),
# (n31:Control {"id":"control_4", "type":"control", "statement":"The organisation shall conduct and document comprehensive impact assessments for AI systems, evaluating potential effects on individuals, groups, and society throughout the system lifecycle. These assessments shall consider fundamental rights, safety implications, environmental impacts, and effects on vulnerable populations. The organisation shall maintain a systematic approach to identifying both existing and emerging risks, including those from third-party components and systems.", "domain":"Risk Management", "master":"RM-2", "topic":"Risk Identification and Impact Assessment"}),
# (n32:Topic {"id":"topic_Risk Identification and Impact Assessment", "type":"topic", "name":"Risk Identification and Impact Assessment"}),
# (n33:Standard {"id":"std_ISO42001_6.1.1-6.1.2 6.1.4 8.4 A.5.2 A.5.3 A.5.4 A.5.5", "type":"standard", "standard":"ISO42001", "reference":"6.1.1-6.1.2 6.1.4 8.4 A.5.2 A.5.3 A.5.4 A.5.5"}),
# (n34:Standard {"id":"std_ISO27001_6.1.2", "type":"standard", "standard":"ISO27001", "reference":"6.1.2"}),
# (n35:Standard {"id":"std_ISO27701_A.7.2.5 A.7.3.10 A.7.4.4", "type":"standard", "standard":"ISO27701", "reference":"A.7.2.5 A.7.3.10 A.7.4.4"}),
# (n36:Standard {"id":"std_EU_AI_ACT_9.9 27.1", "type":"standard", "standard":"EU_AI_ACT", "reference":"9.9 27.1"}),
# (n37:Standard {"id":"std_NIST_RMF_Map 1.1  Map 3.1 Map 3.2 Measure 2.6 Measure 2.7 Measure 2.8 Measure 2.10 Measure 2.12", "type":"standard", "standard":"NIST_RMF", "reference":"Map 1.1 Map 3.1 Map 3.2 Measure 2.6 Measure 2.7 Measure 2.8 Measure 2.10 Measure 2.12"}),
# (n38:Standard {"id":"std_SOC2_CC3.2", "type":"standard", "standard":"SOC2", "reference":"CC3.2"}),
# (n39:Control {"id":"control_5", "type":"control", "statement":"The organisation shall implement appropriate technical and organisational measures to address identified risks, ensuring controls are proportionate to risk levels and organisational risk tolerance. Risk treatment strategies shall be documented and prioritised based on impact and likelihood, with clear accountability for implementation. The organisation shall maintain specific protocols for high-risk AI systems, including quality management systems and compliance verification processes.", "domain":"Risk Management", "master":"RM-3", "topic":"Risk Treatment and Control Implementation"}),
# (n40:Topic {"id":"topic_Risk Treatment and Control Implementation", "type":"topic", "name":"Risk Treatment and Control Implementation"}),
# (n41:Standard {"id":"std_ISO42001_6.1.3", "type":"standard", "standard":"ISO42001", "reference":"6.1.3"}),
# (n42:Standard {"id":"std_ISO27001_6.1.3", "type":"standard", "standard":"ISO27001", "reference":"6.1.3"}),
# (n43:Standard {"id":"std_ISO27701_A.7.4.1 A.7.4.2 A.7.4.4 A.7.4.5", "type":"standard", "standard":"ISO27701", "reference":"A.7.4.1 A.7.4.2 A.7.4.4 A.7.4.5"}),
# (n44:Standard {"id":"std_EU_AI_ACT_8.1 8.2 17.1 9.3 9.4 9.5", "type":"standard", "standard":"EU_AI_ACT", "reference":"8.1 8.2 17.1 9.3 9.4 9.5"}),
# (n45:Standard {"id":"std_NIST_RMF_Manage 1.2 Manage 1.3 Manage 1.4", "type":"standard", "standard":"NIST_RMF", "reference":"Manage 1.2 Manage 1.3 Manage 1.4"}),
# (n46:Standard {"id":"std_SOC2_CC5.1  CC9.1", "type":"standard", "standard":"SOC2", "reference":"CC5.1 CC9.1"}),
# (n47:Control {"id":"control_6", "type":"control", "statement":"The organisation shall implement continuous monitoring processes to track the effectiveness of risk controls and identify emerging risks throughout the AI lifecycle. This shall include mechanisms for detecting and responding to previously unknown risks, regular evaluation of third-party risk exposure, and processes for incident response and recovery. The organisation shall maintain documentation of monitoring activities and ensure appropriate escalation paths for risk-related issues.", "domain":"Risk Management", "master":"RM-4", "topic":"Risk Monitoring and Response"}),
# (n48:Topic {"id":"topic_Risk Monitoring and Response", "type":"topic", "name":"Risk Monitoring and Response"}),
# (n49:Standard {"id":"std_ISO42001_6.1.3 8.1-8.3", "type":"standard", "standard":"ISO42001", "reference":"6.1.3 8.1-8.3"}),
# (n50:Standard {"id":"std_ISO27001_6.1.3 8.1-8.3", "type":"standard", "standard":"ISO27001", "reference":"6.1.3 8.1-8.3"}),
# (n51:Standard {"id":"std_ISO27701_A.7.4.3 A.7.4.9 B.8.2.4 B.8.2.5 B.8.4.3", "type":"standard", "standard":"ISO27701", "reference":"A.7.4.3 A.7.4.9 B.8.2.4 B.8.2.5 B.8.4.3"}),
# (n52:Standard {"id":"std_EU_AI_ACT_9.6", "type":"standard", "standard":"EU_AI_ACT", "reference":"9.6"}),
# (n53:Standard {"id":"std_NIST_RMF_Measure 3.1 Measure 3.2 Manage 2.1 Manage 2.2 Manage 2.3 Manage 3.1 Govern 6.1 Govern 6.2", "type":"standard", "standard":"NIST_RMF", "reference":"Measure 3.1 Measure 3.2 Manage 2.1 Manage 2.2 Manage 2.3 Manage 3.1 Govern 6.1 Govern 6.2"}),
# (n54:Standard {"id":"std_SOC2_CC3.4 CC9.2", "type":"standard", "standard":"SOC2", "reference":"CC3.4 CC9.2"}),
# (n55:Control {"id":"control_7", "type":"control", "statement":"The organisation shall establish, document, and maintain a comprehensive framework for ensuring compliance with applicable AI regulations and standards. This framework shall include processes for identifying relevant requirements, assessing applicability, implementing necessary controls, and verifying ongoing compliance. The organisation shall maintain systematic processes for tracking and implementing new regulatory requirements, conducting conformity assessments, maintaining necessary certifications, and ensuring timely renewal of compliance documentation. Special attention shall be given to high-risk AI system requirements and prohibited practices. The organisation shall implement processes to track changes that may affect compliance status and maintain evidence of continued conformity with legal obligations", "domain":"Regulatory Operations", "master":"RO-1", "topic":"Regulatory Compliance Framework"}),
# (n56:Domain {"id":"domain_Regulatory Operations", "type":"domain", "name":"Regulatory Operations"}),
# (n57:Topic {"id":"topic_Regulatory Compliance Framework", "type":"topic", "name":"Regulatory Compliance Framework"}),
# (n58:Standard {"id":"std_ISO27001_A.18.1", "type":"standard", "standard":"ISO27001", "reference":"A.18.1"}),
# (n59:Standard {"id":"std_ISO27701_18.2.1 A.7.2.1-A.7.2.4 B.8.2.1-B.8.2.2 B.8.2.4-B.8.2.5", "type":"standard", "standard":"ISO27701", "reference":"18.2.1 A.7.2.1-A.7.2.4 B.8.2.1-B.8.2.2 B.8.2.4-B.8.2.5"}),
# (n60:Standard {"id":"std_EU_AI_ACT_5.1 5.2 6.1-6.4 8.1-8.2 40.1 41.1 42.1 43.1-43.4 44.2-44.3 47.1-47.4 49.1-49.3", "type":"standard", "standard":"EU_AI_ACT", "reference":"5.1 5.2 6.1-6.4 8.1-8.2 40.1 41.1 42.1 43.1-43.4 44.2-44.3 47.1-47.4 49.1-49.3"}),
# (n61:Standard {"id":"std_NIST_RMF_Govern 1.1 Map 4.1", "type":"standard", "standard":"NIST_RMF", "reference":"Govern 1.1 Map 4.1"}),
# (n62:Standard {"id":"std_SOC2_CC1.5", "type":"standard", "standard":"SOC2", "reference":"CC1.5"}),
# (n63:Control {"id":"control_8", "type":"control", "statement":"The organisation shall implement mechanisms to ensure appropriate transparency regarding AI systems, including clear notification of AI use, disclosure of automated decision-making, and communication of significant system changes. The organisation shall establish and maintain processes for reporting incidents, safety issues, and non-compliance to relevant authorities and affected stakeholders. This shall include clear procedures for incident detection, assessment, notification timelines, and follow-up actions.", "domain":"Regulatory Operations", "master":"RO-2", "topic":"Transparency, Disclosure and Reporting"}),
# (n64:Topic {"id":"topic_Transparency, Disclosure and Reporting", "type":"topic", "name":"Transparency, Disclosure and Reporting"}),
# (n65:Standard {"id":"std_ISO42001_A.8.3 A.8.5", "type":"standard", "standard":"ISO42001", "reference":"A.8.3 A.8.5"}),
# (n66:Standard {"id":"std_ISO27001_A.6.3", "type":"standard", "standard":"ISO27001", "reference":"A.6.3"}),
# (n67:Standard {"id":"std_ISO27701_6.2.3 A.7.3.2-A.7.3.3 A.7.3.8-A.7.3.9 A.7.5.3-A.7.5.4 B.8.5.3-B.8.5.6", "type":"standard", "standard":"ISO27701", "reference":"6.2.3 A.7.3.2-A.7.3.3 A.7.3.8-A.7.3.9 A.7.5.3-A.7.5.4 B.8.5.3-B.8.5.6"}),
# (n68:Standard {"id":"std_EU_AI_ACT_50.1-50.5 86.1-86.3 20.1 20.2 60.7 60.8", "type":"standard", "standard":"EU_AI_ACT", "reference":"50.1-50.5 86.1-86.3 20.1 20.2 60.7 60.8"}),
# (n69:Standard {"id":"std_NIST_RMF_Govern 6.1 Map 4.1", "type":"standard", "standard":"NIST_RMF", "reference":"Govern 6.1 Map 4.1"}),
# (n70:Standard {"id":"std_SOC2_CC2.3 P1.1 P1.2 P1.3", "type":"standard", "standard":"SOC2", "reference":"CC2.3 P1.1 P1.2 P1.3"}),
# (n71:Control {"id":"control_9", "type":"control", "statement":"The organisation shall maintain comprehensive documentation and records demonstrating compliance with AI regulatory requirements. This shall include technical documentation, conformity assessments, impact analyses, test results, and evidence of ongoing monitoring. The organisation shall establish retention periods aligned with regulatory requirements, implement secure storage systems, and ensure documentation remains accessible to authorised parties throughout required retention periods.", "domain":"Regulatory Operations", "master":"RO-3", "topic":"Record-Keeping"}),
# (n72:Topic {"id":"topic_Record-Keeping", "type":"topic", "name":"Record-Keeping"}),
# (n73:Standard {"id":"std_ISO27001_A.7.2", "type":"standard", "standard":"ISO27001", "reference":"A.7.2"}),
# (n74:Standard {"id":"std_ISO27701_8.2.3 A.7.2.8 A.7.3.1 A.7.4.3 A.7.4.6-A.7.4.8 B.8.2.6 B.8.4.1-B.8.4.2", "type":"standard", "standard":"ISO27701", "reference":"8.2.3 A.7.2.8 A.7.3.1 A.7.4.3 A.7.4.6-A.7.4.8 B.8.2.6 B.8.4.1-B.8.4.2"}),
# (n75:Standard {"id":"std_EU_AI_ACT_11.1 11.3 18.1 19.1 19.2 71.2 71.3", "type":"standard", "standard":"EU_AI_ACT", "reference":"11.1 11.3 18.1 19.1 19.2 71.2 71.3"}),
# (n76:Standard {"id":"std_NIST_RMF_Map 4.1 Measure 2.12", "type":"standard", "standard":"NIST_RMF", "reference":"Map 4.1 Measure 2.12"}),
# (n77:Standard {"id":"std_SOC2_P3.1 P3.2 P3.3", "type":"standard", "standard":"SOC2", "reference":"P3.1 P3.2 P3.3"}),
# (n78:Control {"id":"control_10", "type":"control", "statement":"The organisation shall implement comprehensive post-market monitoring systems for deployed AI systems, including mechanisms for tracking performance, identifying issues, and implementing corrective actions. This shall include processes for reporting incidents to relevant authorities, maintaining required documentation, and conducting periodic reviews of system performance. The organisation shall ensure appropriate escalation paths exist for identified issues and maintain clear procedures for implementing necessary corrective actions.", "domain":"Regulatory Operations", "master":"RO-4", "topic":"Post-Market Monitoring"}),
# (n79:Topic {"id":"topic_Post-Market Monitoring", "type":"topic", "name":"Post-Market Monitoring"}),
# (n80:Standard {"id":"std_ISO42001_A.8.3", "type":"standard", "standard":"ISO42001", "reference":"A.8.3"}),
# (n81:Standard {"id":"std_ISO27701_6.2.3 A.7.3.6-A.7.3.7 A.7.3.10 A.7.4.3 B.8.3.1 B.8.5.7-B.8.5.8", "type":"standard", "standard":"ISO27701", "reference":"6.2.3 A.7.3.6-A.7.3.7 A.7.3.10 A.7.4.3 B.8.3.1 B.8.5.7-B.8.5.8"}),
# (n82:Standard {"id":"std_EU_AI_ACT_72.1-72.4 79.4 80.4-80.5", "type":"standard", "standard":"EU_AI_ACT", "reference":"72.1-72.4 79.4 80.4-80.5"}),
# (n83:Standard {"id":"std_NIST_RMF_Govern 6.1 Measure 2.12", "type":"standard", "standard":"NIST_RMF", "reference":"Govern 6.1 Measure 2.12"}),
# (n84:Control {"id":"control_11", "type":"control", "statement":"The organisation shall establish and maintain comprehensive data governance processes ensuring high-quality data throughout the AI system lifecycle. This shall include documented requirements and procedures for data collection, processing, and validation, ensuring datasets are relevant, representative, and statistically suitable for their intended purpose. The organisation shall implement processes for bias detection and mitigation, maintain clear data provenance records, and ensure data reflects the specific geographical, behavioural, and functional settings where AI systems will be used.", "domain":"System, Data and Model Lifecycle", "master":"LC-1", "topic":"Data Quality and Governance"}),
# (n85:Domain {"id":"domain_System, Data and Model Lifecycle", "type":"domain", "name":"System, Data and Model Lifecycle"}),
# (n86:Topic {"id":"topic_Data Quality and Governance", "type":"topic", "name":"Data Quality and Governance"}),
# (n87:Standard {"id":"std_ISO42001_A.7.2-A.7.6", "type":"standard", "standard":"ISO42001", "reference":"A.7.2-A.7.6"}),
# (n88:Standard {"id":"std_ISO27701_A.7.4.1-A.7.4.2 A.7.4.6-A.7.4.8 B.8.4.1-B.8.4.2", "type":"standard", "standard":"ISO27701", "reference":"A.7.4.1-A.7.4.2 A.7.4.6-A.7.4.8 B.8.4.1-B.8.4.2"}),
# (n89:Standard {"id":"std_EU_AI_ACT_10.1-10.6", "type":"standard", "standard":"EU_AI_ACT", "reference":"10.1-10.6"}),
# (n90:Standard {"id":"std_NIST_RMF_Map 2.1", "type":"standard", "standard":"NIST_RMF", "reference":"Map 2.1"}),
# (n91:Control {"id":"control_12", "type":"control", "statement":"The organisation shall define, document, and maintain processes for responsible AI system development across the entire lifecycle, from requirements specification through deployment and eventual decommissioning. The organisation shall maintain clear records of system objectives, technical implementation decisions, and operational constraints throughout development and deployment phases.", "domain":"System, Data and Model Lifecycle", "master":"LC-2", "topic":"System Development and Lifecycle Management"}),
# (n92:Topic {"id":"topic_System Development and Lifecycle Management", "type":"topic", "name":"System Development and Lifecycle Management"}),
# (n93:Standard {"id":"std_ISO42001_A.6.1.2-A.6.1.3 A.6.2.2-A.6.2.3 A.6.2.5", "type":"standard", "standard":"ISO42001", "reference":"A.6.1.2-A.6.1.3 A.6.2.2-A.6.2.3 A.6.2.5"}),
# (n94:Standard {"id":"std_ISO27701_A.7.4.1-A.7.4.2 A.7.4.5-A.7.4.8 B.8.4.1-B.8.4.2", "type":"standard", "standard":"ISO27701", "reference":"A.7.4.1-A.7.4.2 A.7.4.5-A.7.4.8 B.8.4.1-B.8.4.2"}),
# (n95:Standard {"id":"std_NIST_RMF_Map 1.6 Govern 1.7", "type":"standard", "standard":"NIST_RMF", "reference":"Map 1.6 Govern 1.7"}),
# (n96:Standard {"id":"std_SOC2_CC8.1 CC8.2", "type":"standard", "standard":"SOC2", "reference":"CC8.1 CC8.2"}),
# (n97:Control {"id":"control_13", "type":"control", "statement":"The organisation shall document and maintain inventories of all resources required for AI system development and operation, including data resources, tooling, computing infrastructure, and human competencies. This shall include clear allocation of responsibilities, documentation of system dependencies, and maintenance of resource specifications throughout the system lifecycle.", "domain":"System, Data and Model Lifecycle", "master":"LC-3", "topic":"Resource Management and Infrastructure"}),
# (n98:Topic {"id":"topic_Resource Management and Infrastructure", "type":"topic", "name":"Resource Management and Infrastructure"}),
# (n99:Standard {"id":"std_ISO42001_A.4.3 A.4.5 A.4.6 A.10.2", "type":"standard", "standard":"ISO42001", "reference":"A.4.3 A.4.5 A.4.6 A.10.2"}),
# (n100:Standard {"id":"std_ISO27001_A.8.1 A.8.2", "type":"standard", "standard":"ISO27001", "reference":"A.8.1 A.8.2"}),
# (n101:Standard {"id":"std_ISO27701_A.7.2.6 A.7.2.7 B.8.5.6", "type":"standard", "standard":"ISO27701", "reference":"A.7.2.6 A.7.2.7 B.8.5.6"}),
# (n102:Standard {"id":"std_NIST_RMF_Govern 1.6", "type":"standard", "standard":"NIST_RMF", "reference":"Govern 1.6"}),
# (n103:Control {"id":"control_14", "type":"control", "statement":"The organisation shall maintain comprehensive technical documentation demonstrating compliance throughout the AI system lifecycle. This shall include system characteristics, design specifications, validation results, and operational logs. The organisation shall implement automated logging mechanisms to capture system events, maintain documentation for required retention periods, and ensure documentation remains accessible to relevant stakeholders.", "domain":"System, Data and Model Lifecycle", "master":"LC-4", "topic":"Technical Documentation"}),
# (n104:Topic {"id":"topic_Technical Documentation", "type":"topic", "name":"Technical Documentation"}),
# (n105:Standard {"id":"std_ISO42001_7.5.1-7.5.3 A.6.2.7 A.6.2.8", "type":"standard", "standard":"ISO42001", "reference":"7.5.1-7.5.3 A.6.2.7 A.6.2.8"}),
# (n106:Standard {"id":"std_ISO27001_7.5.1-7.5.3", "type":"standard", "standard":"ISO27001", "reference":"7.5.1-7.5.3"}),
# (n107:Standard {"id":"std_ISO27701_A.7.2.8 A.7.5.3 A.7.5.4 B.8.2.6 B.8.5.3", "type":"standard", "standard":"ISO27701", "reference":"A.7.2.8 A.7.5.3 A.7.5.4 B.8.2.6 B.8.5.3"}),
# (n108:Standard {"id":"std_EU_AI_ACT_11.1-11.3 12.1-12.3 18.1", "type":"standard", "standard":"EU_AI_ACT", "reference":"11.1-11.3 12.1-12.3 18.1"}),
# (n109:Standard {"id":"std_NIST_RMF_Map 2.2 Map 3.3", "type":"standard", "standard":"NIST_RMF", "reference":"Map 2.2 Map 3.3"}),
# (n110:Control {"id":"control_15", "type":"control", "statement":"The organisation shall establish and maintain comprehensive processes for managing changes to AI systems throughout their lifecycle. This shall include documented procedures for proposing, evaluating, testing, and implementing changes to models, data, or system components. The organisation shall maintain detailed version control of all system elements, including models, datasets, and software components, with clear records of modifications and their rationale. Changes shall be tested and validated before deployment, with documentation updated to reflect current system state.", "domain":"System, Data and Model Lifecycle", "master":"LC-5", "topic":"Change Management & Version Control"}),
# (n111:Topic {"id":"topic_Change Management & Version Control", "type":"topic", "name":"Change Management & Version Control"}),
# (n112:Standard {"id":"std_ISO42001_A.6.2.5", "type":"standard", "standard":"ISO42001", "reference":"A.6.2.5"}),
# (n113:Standard {"id":"std_ISO27001_A.12.2", "type":"standard", "standard":"ISO27001", "reference":"A.12.2"}),
# (n114:Standard {"id":"std_ISO27701_A.7.3.7 B.8.5.7 B.8.5.8", "type":"standard", "standard":"ISO27701", "reference":"A.7.3.7 B.8.5.7 B.8.5.8"}),
# (n115:Standard {"id":"std_EU_AI_ACT_11.3", "type":"standard", "standard":"EU_AI_ACT", "reference":"11.3"}),
# (n116:Control {"id":"control_16", "type":"control", "statement":"The organisation shall establish and maintain a comprehensive security governance framework that encompasses security risk management, security policies, standards, and architectures that guide the implementation of security controls across the organisation. The organisation shall ensure continuous monitoring of control effectiveness, manages security incidents, and maintains business continuity capabilities while overseeing third-party security requirements.", "domain":"Security", "master":"SE-1", "topic":"Security Governance, Architecture and Engineering"}),
# (n117:Domain {"id":"domain_Security", "type":"domain", "name":"Security"}),
# (n118:Topic {"id":"topic_Security Governance, Architecture and Engineering", "type":"topic", "name":"Security Governance, Architecture and Engineering"}),
# (n119:Standard {"id":"std_ISO27001_A.5.1-A.5.2 A.6.1-A.6.2 A.6.5 A.7.1-A.7.4 A.12.1-A.12.3 A.17.1-A.17.2 A.18.1-A.18.2", "type":"standard", "standard":"ISO27001", "reference":"A.5.1-A.5.2 A.6.1-A.6.2 A.6.5 A.7.1-A.7.4 A.12.1-A.12.3 A.17.1-A.17.2 A.18.1-A.18.2"}),
# (n120:Standard {"id":"std_ISO27701_14.2.1 14.2.2", "type":"standard", "standard":"ISO27701", "reference":"14.2.1 14.2.2"}),
# (n121:Standard {"id":"std_SOC2_CC2.3 CC3.1 CC3.2 CC5.2 CC7.2 CC7.3 CC9.3", "type":"standard", "standard":"SOC2", "reference":"CC2.3 CC3.1 CC3.2 CC5.2 CC7.2 CC7.3 CC9.3"}),
# (n122:Control {"id":"control_17", "type":"control", "statement":"The organisation shall implement and maintains comprehensive identity and access management controls governing authentication, authorisation, and access monitoring across all systems and applications. This includes the complete lifecycle of identity management from screening to provisioning through deprovisioning, ensuring appropriate access levels are maintained and regularly reviewed. The organisation shall implement strong authentication mechanisms and maintains detailed access logs for all critical systems.", "domain":"Security", "master":"SE-2", "topic":"Identity & Access Management"}),
# (n123:Topic {"id":"topic_Identity & Access Management", "type":"topic", "name":"Identity & Access Management"}),
# (n124:Standard {"id":"std_ISO27001_A.9.1 A.9.2 A.9.3 A.9.4", "type":"standard", "standard":"ISO27001", "reference":"A.9.1 A.9.2 A.9.3 A.9.4"}),
# (n125:Standard {"id":"std_ISO27701_9.2.1 9.2.2 9.2.4", "type":"standard", "standard":"ISO27701", "reference":"9.2.1 9.2.2 9.2.4"}),
# (n126:Standard {"id":"std_SOC2_CC6.1 CC6.2 CC6.3", "type":"standard", "standard":"SOC2", "reference":"CC6.1 CC6.2 CC6.3"}),
# (n127:Control {"id":"control_18", "type":"control", "statement":"The organisation shall ensure all software development and deployment activities follow secure development practices throughout the system development lifecycle. This includes implementing secure coding standards, conducting security testing, managing secure configurations, and maintaining robust change management procedures for all production systems. The organisation shall regularly assess applications for security vulnerabilities and maintain secure development environments.", "domain":"Security", "master":"SE-3", "topic":"Software Security"}),
# (n128:Topic {"id":"topic_Software Security", "type":"topic", "name":"Software Security"}),
# (n129:Standard {"id":"std_ISO27001_A.14.1 A.14.2 A.12.2", "type":"standard", "standard":"ISO27001", "reference":"A.14.1 A.14.2 A.12.2"}),
# (n130:Standard {"id":"std_SOC2_CC5.2 CC7.1", "type":"standard", "standard":"SOC2", "reference":"CC5.2 CC7.1"}),
# (n131:Control {"id":"control_19", "type":"control", "statement":"The organisation shall protect data throughout its lifecycle using appropriate technical and procedural controls, including classification, encryption, and secure handling procedures. This encompasses structured and unstructured data across all storage locations and transmission paths. The organisation shall maintain comprehensive data protection mechanisms, including backup systems, encryption standards, and secure disposal procedures, while ensuring appropriate data classification and handling requirements are enforced.", "domain":"Security", "master":"SE-4", "topic":"Data Security"}),
# (n132:Topic {"id":"topic_Data Security", "type":"topic", "name":"Data Security"}),
# (n133:Standard {"id":"std_ISO27001_A.8.1-A.8.7 A.10.1 A.10.2 A.12.4 A.12.5 A.14.3", "type":"standard", "standard":"ISO27001", "reference":"A.8.1-A.8.7 A.10.1 A.10.2 A.12.4 A.12.5 A.14.3"}),
# (n134:Standard {"id":"std_ISO27701_8.2.4 8.3.1 8.3.2 8.3.3 10.2.1 10.2.2 11.2.2", "type":"standard", "standard":"ISO27701", "reference":"8.2.4 8.3.1 8.3.2 8.3.3 10.2.1 10.2.2 11.2.2"}),
# (n135:Standard {"id":"std_SOC2_CC6.4-CC6.7 C1.1 C1.2 P5.1-P5.4 P5.6", "type":"standard", "standard":"SOC2", "reference":"CC6.4-CC6.7 C1.1 C1.2 P5.1-P5.4 P5.6"}),
# (n136:Control {"id":"control_20", "type":"control", "statement":"The organisation shall implement and maintain comprehensive network security controls to protect against unauthorised access, ensure secure communications, and maintain the confidentiality and integrity of data in transit. This includes implementing secure network architectures, maintaining network monitoring capabilities, and ensuring appropriate network segmentation. The organisation shall regularly assess network security controls and maintain comprehensive network logging and monitoring capabilities.", "domain":"Security", "master":"SE-5", "topic":"Network Security"}),
# (n137:Topic {"id":"topic_Network Security", "type":"topic", "name":"Network Security"}),
# (n138:Standard {"id":"std_ISO27001_A.13.1-A.13.3 A.12.4 A.12.6 A.10.1 A.10.2", "type":"standard", "standard":"ISO27001", "reference":"A.13.1-A.13.3 A.12.4 A.12.6 A.10.1 A.10.2"}),
# (n139:Standard {"id":"std_ISO27701_13.2.1", "type":"standard", "standard":"ISO27701", "reference":"13.2.1"}),
# (n140:Standard {"id":"std_SOC2_CC6.6 CC7.1 CC7.2", "type":"standard", "standard":"SOC2", "reference":"CC6.6 CC7.1 CC7.2"}),
# (n141:Control {"id":"control_21", "type":"control", "statement":"The organisation shall implement and maintain comprehensive physical security controls to protect information assets, including facilities, equipment, and supporting infrastructure from unauthorised access and environmental threats. This includes maintaining secure physical perimeters, implementing environmental controls, monitoring physical access, and ensuring appropriate protection for equipment and supporting infrastructure.", "domain":"Security", "master":"SE-6", "topic":"Physical Security"}),
# (n142:Topic {"id":"topic_Physical Security", "type":"topic", "name":"Physical Security"}),
# (n143:Standard {"id":"std_ISO27001_A.11.1 A.11.2 A.11.3 A.11.4 A.11.5", "type":"standard", "standard":"ISO27001", "reference":"A.11.1 A.11.2 A.11.3 A.11.4 A.11.5"}),
# (n144:Standard {"id":"std_ISO27701_11.2.1", "type":"standard", "standard":"ISO27701", "reference":"11.2.1"}),
# (n145:Standard {"id":"std_SOC2_CC6.1", "type":"standard", "standard":"SOC2", "reference":"CC6.1"}),
# (n146:Control {"id":"control_22", "type":"control", "statement":"The organisation shall implement mechanisms for meaningful human oversight of AI systems, ensuring humans maintain appropriate control over AI decision-making. This includes clearly defined procedures for human monitoring, intervention capabilities, and authority to override AI systems when necessary. Personnel responsible for oversight must receive appropriate training and have sufficient competence and authority to fulfill their responsibilities effectively.", "domain":"Safe Responsible AI", "master":"RS-1", "topic":"Human Oversight and Intervention"}),
# (n147:Domain {"id":"domain_Safe Responsible AI", "type":"domain", "name":"Safe Responsible AI"}),
# (n148:Topic {"id":"topic_Human Oversight and Intervention", "type":"topic", "name":"Human Oversight and Intervention"}),
# (n149:Standard {"id":"std_ISO42001_A.9.2 A.9.3 A.9.4", "type":"standard", "standard":"ISO42001", "reference":"A.9.2 A.9.3 A.9.4"}),
# (n150:Standard {"id":"std_ISO27001_A.18.1.1  A.18.2.2 A.6.1 A.6.2", "type":"standard", "standard":"ISO27001", "reference":"A.18.1.1 A.18.2.2 A.6.1 A.6.2"}),
# (n151:Standard {"id":"std_ISO27701_7.2.2 7.2.5", "type":"standard", "standard":"ISO27701", "reference":"7.2.2 7.2.5"}),
# (n152:Standard {"id":"std_EU_AI_ACT_14.1-14.5 26.2 4.1", "type":"standard", "standard":"EU_AI_ACT", "reference":"14.1-14.5 26.2 4.1"}),
# (n153:Standard {"id":"std_NIST_RMF_Govern 3.2 Map 3.4 Map 3.5", "type":"standard", "standard":"NIST_RMF", "reference":"Govern 3.2 Map 3.4 Map 3.5"}),
# (n154:Standard {"id":"std_SOC2_CC1.1  CC2.1", "type":"standard", "standard":"SOC2", "reference":"CC1.1 CC2.1"}),
# (n155:Control {"id":"control_23", "type":"control", "statement":"The organisation shall establish and maintain processes to prevent AI systems from producing outputs that could cause harm to individuals, groups, or society. This includes comprehensive impact assessments, monitoring for potential harms, and implementation of safeguards to prevent prohibited uses or manipulative practices. The organisation must maintain documented evidence of harm prevention measures and regularly assess their effectiveness.", "domain":"Safe Responsible AI", "master":"RS-2", "topic":"Safety"}),
# (n156:Topic {"id":"topic_Safety", "type":"topic", "name":"Safety"}),
# (n157:Standard {"id":"std_ISO42001_A.5.2 A.5.3 A.5.4 A.5.5", "type":"standard", "standard":"ISO42001", "reference":"A.5.2 A.5.3 A.5.4 A.5.5"}),
# (n158:Standard {"id":"std_ISO27001_A.12.1", "type":"standard", "standard":"ISO27001", "reference":"A.12.1"}),
# (n159:Standard {"id":"std_ISO27701_7.2.3 7.2.4", "type":"standard", "standard":"ISO27701", "reference":"7.2.3 7.2.4"}),
# (n160:Standard {"id":"std_EU_AI_ACT_5.1 5.2 9.1-9.3", "type":"standard", "standard":"EU_AI_ACT", "reference":"5.1 5.2 9.1-9.3"}),
# (n161:Standard {"id":"std_NIST_RMF_Map 1.1 Map 3.1 Map 3.2 Measure 3.1 Measure 3.2", "type":"standard", "standard":"NIST_RMF", "reference":"Map 1.1 Map 3.1 Map 3.2 Measure 3.1 Measure 3.2"}),
# (n162:Standard {"id":"std_SOC2_CC4.1 CC5.1", "type":"standard", "standard":"SOC2", "reference":"CC4.1 CC5.1"}),
# (n163:Control {"id":"control_24", "type":"control", "statement":"The organisation shall ensure AI systems demonstrate consistent and reliable performance across their intended operating conditions, including edge cases and unexpected scenarios. Systems must be resilient against errors, adversarial attacks, and data quality issues. Regular testing and monitoring shall be conducted to verify robustness, with particular attention to system behavior under stress conditions or when encountering novel situations.", "domain":"Safe Responsible AI", "master":"RS-3", "topic":"Robustness"}),
# (n164:Topic {"id":"topic_Robustness", "type":"topic", "name":"Robustness"}),
# (n165:Standard {"id":"std_ISO42001_A.9.4", "type":"standard", "standard":"ISO42001", "reference":"A.9.4"}),
# (n166:Standard {"id":"std_ISO27001_A.17.1 A.17.2", "type":"standard", "standard":"ISO27001", "reference":"A.17.1 A.17.2"}),
# (n167:Standard {"id":"std_ISO27701_7.2.8", "type":"standard", "standard":"ISO27701", "reference":"7.2.8"}),
# (n168:Standard {"id":"std_EU_AI_ACT_8.1 8.2 15.1 15.4 15.5", "type":"standard", "standard":"EU_AI_ACT", "reference":"8.1 8.2 15.1 15.4 15.5"}),
# (n169:Standard {"id":"std_NIST_RMF_Map 2.1 Map 2.2 Measure 4.2 Measure 4.3", "type":"standard", "standard":"NIST_RMF", "reference":"Map 2.1 Map 2.2 Measure 4.2 Measure 4.3"}),
# (n170:Standard {"id":"std_SOC2_CC7.1 CC8.1", "type":"standard", "standard":"SOC2", "reference":"CC7.1 CC8.1"}),
# (n171:Control {"id":"control_25", "type":"control", "statement":"The organisation shall ensure AI systems decisions and outputs can be appropriately explained and interpreted by relevant stakeholders. This includes maintaining comprehensive documentation of system behaviour, providing clear explanations of AI-driven decisions when required, and ensuring transparency about system capabilities and limitations. Methods for generating explanations must be appropriate to the context and audience.", "domain":"Safe Responsible AI", "master":"RS-4", "topic":"Explainability and Interpretability"}),
# (n172:Topic {"id":"topic_Explainability and Interpretability", "type":"topic", "name":"Explainability and Interpretability"}),
# (n173:Standard {"id":"std_ISO42001_A.5.3", "type":"standard", "standard":"ISO42001", "reference":"A.5.3"}),
# (n174:Standard {"id":"std_ISO27701_7.2.1", "type":"standard", "standard":"ISO27701", "reference":"7.2.1"}),
# (n175:Standard {"id":"std_EU_AI_ACT_50.2 50.3 50.4 50.5", "type":"standard", "standard":"EU_AI_ACT", "reference":"50.2 50.3 50.4 50.5"}),
# (n176:Standard {"id":"std_NIST_RMF_Govern 4.2 Map 2.2 Map 2.3 Measure 2.8", "type":"standard", "standard":"NIST_RMF", "reference":"Govern 4.2 Map 2.2 Map 2.3 Measure 2.8"}),
# (n177:Standard {"id":"std_SOC2_CC2.2 CC2.3", "type":"standard", "standard":"SOC2", "reference":"CC2.2 CC2.3"}),
# (n178:Control {"id":"control_26", "type":"control", "statement":"The organisation shall implement processes to identify, assess, and mitigate unfair bias in AI systems throughout their lifecycle. This includes ensuring training data is representative and appropriate, regularly testing for disparate impact across protected characteristics, and maintaining documented evidence of fairness assessments and mitigation measures. The organisation must regularly validate that AI systems maintain fairness standards in operation.", "domain":"Safe Responsible AI", "master":"RS-5", "topic":"Fairness and Bias Management"}),
# (n179:Topic {"id":"topic_Fairness and Bias Management", "type":"topic", "name":"Fairness and Bias Management"}),
# (n180:Standard {"id":"std_ISO42001_A.5.4", "type":"standard", "standard":"ISO42001", "reference":"A.5.4"}),
# (n181:Standard {"id":"std_ISO27701_7.2.6", "type":"standard", "standard":"ISO27701", "reference":"7.2.6"}),
# (n182:Standard {"id":"std_EU_AI_ACT_5.1 26.4", "type":"standard", "standard":"EU_AI_ACT", "reference":"5.1 26.4"}),
# (n183:Standard {"id":"std_NIST_RMF_Measure 2.11  Govern 5.2  Measure 2.2", "type":"standard", "standard":"NIST_RMF", "reference":"Measure 2.11 Govern 5.2 Measure 2.2"}),
# (n184:Standard {"id":"std_SOC2_CC1.3 CC5.3", "type":"standard", "standard":"SOC2", "reference":"CC1.3 CC5.3"}),
# (n185:Control {"id":"control_27", "type":"control", "statement":"The organisation shall implement privacy by design principles in all AI systems, ensuring privacy considerations are embedded from initial planning through system retirement. This includes establishing and maintaining comprehensive privacy policies, conducting privacy impact assessments, defining clear privacy roles and responsibilities, and integrating privacy requirements into project management processes. The organisation shall establish privacy governance structures, maintain documentation of privacy decisions, regularly review privacy controls for effectiveness, and ensure special categories of personal data are processed only when strictly necessary and with appropriate safeguards. Senior management shall demonstrate commitment to privacy through resource allocation and oversight of privacy initiatives.", "domain":"Privacy", "master":"PR-1", "topic":"Privacy by Design and Governance"}),
# (n186:Domain {"id":"domain_Privacy", "type":"domain", "name":"Privacy"}),
# (n187:Topic {"id":"topic_Privacy by Design and Governance", "type":"topic", "name":"Privacy by Design and Governance"}),
# (n188:Standard {"id":"std_ISO27701_6.1.1 6.1.2 6.2.1-6.2.4 7.2.1-7.2.3 7.2.5 7.2.7 12.2.1 A.7.4.1-A.7.4.9 B.8.4", "type":"standard", "standard":"ISO27701", "reference":"6.1.1 6.1.2 6.2.1-6.2.4 7.2.1-7.2.3 7.2.5 7.2.7 12.2.1 A.7.4.1-A.7.4.9 B.8.4"}),
# (n189:Standard {"id":"std_EU_AI_ACT_10.5 26.9 27.4", "type":"standard", "standard":"EU_AI_ACT", "reference":"10.5 26.9 27.4"}),
# (n190:Standard {"id":"std_SOC2_P1.1 P1.2 P1.3", "type":"standard", "standard":"SOC2", "reference":"P1.1 P1.2 P1.3"}),
# (n191:Control {"id":"control_28", "type":"control", "statement":"The organisation shall implement operational processes for the responsible collection, use, storage, and disposal of personal data in AI systems. This includes maintaining data inventories, implementing data classification schemes, managing data retention schedules, and ensuring appropriate data handling throughout the information lifecycle. The organisation shall obtain and maintain records of consent for data processing, provide individuals with access to their data, implement processes for handling data subject requests, and ensure data quality standards are maintained. Clear procedures for data minimisation, purpose limitation, and secure disposal shall be established and followed.", "domain":"Privacy", "master":"PR-2", "topic":"Personal Data Management"}),
# (n192:Topic {"id":"topic_Personal Data Management", "type":"topic", "name":"Personal Data Management"}),
# (n193:Standard {"id":"std_ISO27701_8.2.1-8.2.4  8.3.1-8.3.3 A.7.2.1-A.7.2.8 A.7.3.1-A.7.3.10 7.4.5 A.7.5.1-A.7.5.4 B.8.2 B.8.3 B.8.4.2 B.8.5", "type":"standard", "standard":"ISO27701", "reference":"8.2.1-8.2.4 8.3.1-8.3.3 A.7.2.1-A.7.2.8 A.7.3.1-A.7.3.10 7.4.5 A.7.5.1-A.7.5.4 B.8.2 B.8.3 B.8.4.2 B.8.5"}),
# (n194:Standard {"id":"std_SOC2_P2.1 P2.2 P3.1-P3.3 P4.1-P4.3", "type":"standard", "standard":"SOC2", "reference":"P2.1 P2.2 P3.1-P3.3 P4.1-P4.3"}),
# (n195:Control {"id":"control_29", "type":"control", "statement":"The organisation shall establish processes to monitor compliance with privacy requirements, detect and respond to privacy incidents, and ensure continuous improvement of privacy controls. This includes conducting regular privacy audits, monitoring data processing activities, managing privacy incidents, ensuring supplier compliance with privacy requirements, and maintaining business continuity plans that address privacy considerations. The organisation shall implement privacy metrics, conduct regular assessments, comply with breach notification requirements, and demonstrate ongoing compliance with applicable privacy regulations through documented evidence.", "domain":"Privacy", "master":"PR-3", "topic":"Privacy Compliance and Monitoring"}),
# (n196:Topic {"id":"topic_Privacy Compliance and Monitoring", "type":"topic", "name":"Privacy Compliance and Monitoring"}),
# (n197:Standard {"id":"std_ISO27701_12.2.2 15.2.1 16.2.1 16.2.2 17.2.1 18.2.1 18.2.2 A.7.2.5-A.7.2.7 A.7.3.6 B.8.2.4 B.8.2.5", "type":"standard", "standard":"ISO27701", "reference":"12.2.2 15.2.1 16.2.1 16.2.2 17.2.1 18.2.1 18.2.2 A.7.2.5-A.7.2.7 A.7.3.6 B.8.2.4 B.8.2.5"}),
# (n198:Standard {"id":"std_SOC2_P6.1 P6.2 P6.3 P6.4 P6.5", "type":"standard", "standard":"SOC2", "reference":"P6.1 P6.2 P6.3 P6.4 P6.5"}),
# (n199:Control {"id":"control_30", "type":"control", "statement":"The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies in AI systems to protect personal data and ensure privacy by default. This includes implementing encryption for data at rest and in transit, role-based access control mechanisms, data minimisation techniques, anonymisation and pseudonymisation methods, and secure deletion capabilities. The organisation shall ensure these mechanisms are appropriate for the sensitivity of the data, regularly tested for effectiveness, and updated as privacy-enhancing technologies evolve. This includes how technical controls are documented, validated, and integrated into the system architecture to provide defense in depth for privacy protection.", "domain":"Privacy", "master":"PR-4", "topic":"Privacy-Enhancing Technologies and Mechanisms"}),
# (n200:Topic {"id":"topic_Privacy-Enhancing Technologies and Mechanisms", "type":"topic", "name":"Privacy-Enhancing Technologies and Mechanisms"}),
# (n201:Standard {"id":"std_ISO27701_9.2.1-9.2.4 10.2.1-10.2.2 11.2.1-11.2.2 13.2.1 14.2.1-14.2.2 A.7.4.5 A.7.4.9 B.8.4.3", "type":"standard", "standard":"ISO27701", "reference":"9.2.1-9.2.4 10.2.1-10.2.2 11.2.1-11.2.2 13.2.1 14.2.1-14.2.2 A.7.4.5 A.7.4.9 B.8.4.3"}),
# (n202:Standard {"id":"std_SOC2_P5.1 P5.2 P5.3 P5.4 P5.5 P5.6", "type":"standard", "standard":"SOC2", "reference":"P5.1 P5.2 P5.3 P5.4 P5.5 P5.6"}),
# (n203:Control {"id":"control_31", "type":"control", "statement":"The organisation shall establish and maintain comprehensive internal assessment and audit procedures for AI systems throughout their lifecycle. This includes documented verification of controls and validation of system behavior in both controlled and real-world conditions. Internal audits must evaluate compliance with organisational policies and procedures. Internal assessment and audit activities must cover normal operations, edge cases, and stress conditions. The organisation shall maintain evidence of all audit activities, findings, and remediation efforts.", "domain":"Assurance and Audit", "master":"AA-1", "topic":"Internal Assessment & Audit"}),
# (n204:Domain {"id":"domain_Assurance and Audit", "type":"domain", "name":"Assurance and Audit"}),
# (n205:Topic {"id":"topic_Internal Assessment & Audit", "type":"topic", "name":"Internal Assessment & Audit"}),
# (n206:Standard {"id":"std_ISO42001_9.1 9.2 9.3 A.6.2.4", "type":"standard", "standard":"ISO42001", "reference":"9.1 9.2 9.3 A.6.2.4"}),
# (n207:Standard {"id":"std_ISO27001_9.1 9.2 9.3 A.18.2", "type":"standard", "standard":"ISO27001", "reference":"9.1 9.2 9.3 A.18.2"}),
# (n208:Standard {"id":"std_ISO27701_8.2.3 18.2.2 A.7.2.5 A.7.4.3", "type":"standard", "standard":"ISO27701", "reference":"8.2.3 18.2.2 A.7.2.5 A.7.4.3"}),
# (n209:Standard {"id":"std_EU_AI_ACT_9.7-9.8 17.1-17.2 60.1-60.9 61.1 61.2", "type":"standard", "standard":"EU_AI_ACT", "reference":"9.7-9.8 17.1-17.2 60.1-60.9 61.1 61.2"}),
# (n210:Standard {"id":"std_NIST_RMF_Map 2.3  Measure 2.1  Measure 2.3  Measure 2.5", "type":"standard", "standard":"NIST_RMF", "reference":"Map 2.3 Measure 2.1 Measure 2.3 Measure 2.5"}),
# (n211:Standard {"id":"std_SOC2_PI1.1 PI1.2 CC4.1", "type":"standard", "standard":"SOC2", "reference":"PI1.1 PI1.2 CC4.1"}),
# (n212:Control {"id":"control_32", "type":"control", "statement":"The organisation shall ensure regular independent assessments of AI systems are conducted and maintain necessary certifications. Independent assessors must have appropriate expertise and authority to evaluate compliance with regulatory requirements and performance standards. The organisation shall obtain and maintain required certifications, track certification status, and implement corrective actions when gaps are identified. Assessment and certification activities must be documented, including findings and evidence of remediation.", "domain":"Assurance and Audit", "master":"AA-2", "topic":"Independent Assessment and Certification"}),
# (n213:Topic {"id":"topic_Independent Assessment and Certification", "type":"topic", "name":"Independent Assessment and Certification"}),
# (n214:Standard {"id":"std_ISO42001_9.1 9.3 10.1 10.2", "type":"standard", "standard":"ISO42001", "reference":"9.1 9.3 10.1 10.2"}),
# ...
# (n295:Topic {"id":"topic_Incident Reporting and Notification", "type":"topic", "name":"Incident Reporting and Notification"}),
# (n296:Standard {"id":"std_ISO27001_A.16.1 A.16.2", "type":"standard", "standard":"ISO27001", "reference":"A.16.1 A.16.2"}),
# (n297:Standard {"id":"std_ISO27701_16.2.2 B.8.5.4 B.8.5.5", "type":"standard", "standard":"ISO27701", "reference":"16.2.2 B.8.5.4 B.8.5.5"}),
# (n298:Standard {"id":"std_EU_AI_ACT_73.1-73.5 73.9 73.10", "type":"standard", "standard":"EU_AI_ACT", "reference":"73.1-73.5 73.9 73.10"}),
# (n299:Standard {"id":"std_SOC2_P6.3 P6.4", "type":"standard", "standard":"SOC2", "reference":"P6.3 P6.4"}),
# (n300:Control {"id":"control_43", "type":"control", "statement":"The organisation shall analyse incidents to identify root causes, assess the effectiveness of response measures, and implement improvements to prevent recurrence. This includes conducting post-incident reviews, documenting lessons learned, updating incident response procedures based on experience, and verifying the effectiveness of corrective actions. The organisation must maintain records of all incident analyses and resulting improvements.", "domain":"Incident Management", "master":"IM-3", "topic":"Incident Analysis and Improvement"}),
# (n301:Topic {"id":"topic_Incident Analysis and Improvement", "type":"topic", "name":"Incident Analysis and Improvement"}),
# (n302:Standard {"id":"std_ISO27001_A.16.3", "type":"standard", "standard":"ISO27001", "reference":"A.16.3"}),
# (n303:Standard {"id":"std_ISO27701_16.2.1", "type":"standard", "standard":"ISO27701", "reference":"16.2.1"}),
# (n304:Standard {"id":"std_SOC2_P6.5", "type":"standard", "standard":"SOC2", "reference":"P6.5"}),
# (n0)-[:CONNECTED {"rel":"maps_to"}]-(n3),
# (n0)-[:CONNECTED {"rel":"maps_to"}]-(n4),
# (n0)-[:CONNECTED {"rel":"maps_to"}]-(n5),
# (n0)-[:CONNECTED {"rel":"maps_to"}]-(n6),
# (n0)-[:CONNECTED {"rel":"maps_to"}]-(n7),
# (n0)-[:CONNECTED {"rel":"maps_to"}]-(n8),
# (n1)-[:CONNECTED {"rel":"contains"}]-(n2),
# (n1)-[:CONNECTED {"rel":"contains"}]-(n10),
# (n1)-[:CONNECTED {"rel":"contains"}]-(n17),
# (n2)-[:CONNECTED {"rel":"has_control"}]-(n0),
# (n9)-[:CONNECTED {"rel":"maps_to"}]-(n11),
# (n9)-[:CONNECTED {"rel":"maps_to"}]-(n12),
# (n9)-[:CONNECTED {"rel":"maps_to"}]-(n13),
# (n9)-[:CONNECTED {"rel":"maps_to"}]-(n14),
# (n9)-[:CONNECTED {"rel":"maps_to"}]-(n15),
# (n10)-[:CONNECTED {"rel":"has_control"}]-(n9),
# (n16)-[:CONNECTED {"rel":"maps_to"}]-(n18),
# (n16)-[:CONNECTED {"rel":"maps_to"}]-(n19),
# (n16)-[:CONNECTED {"rel":"maps_to"}]-(n20),
# (n16)-[:CONNECTED {"rel":"maps_to"}]-(n21),
# (n17)-[:CONNECTED {"rel":"has_control"}]-(n16),
# (n22)-[:CONNECTED {"rel":"maps_to"}]-(n25),
# (n22)-[:CONNECTED {"rel":"maps_to"}]-(n26),
# (n22)-[:CONNECTED {"rel":"maps_to"}]-(n27),
# (n22)-[:CONNECTED {"rel":"maps_to"}]-(n28),
# (n22)-[:CONNECTED {"rel":"maps_to"}]-(n29),
# (n22)-[:CONNECTED {"rel":"maps_to"}]-(n30),
# (n23)-[:CONNECTED {"rel":"contains"}]-(n24),
# (n23)-[:CONNECTED {"rel":"contains"}]-(n32),
# (n23)-[:CONNECTED {"rel":"contains"}]-(n40),
# (n23)-[:CONNECTED {"rel":"contains"}]-(n48),
# (n24)-[:CONNECTED {"rel":"has_control"}]-(n22),
# (n31)-[:CONNECTED {"rel":"maps_to"}]-(n33),
# (n31)-[:CONNECTED {"rel":"maps_to"}]-(n34),
# (n31)-[:CONNECTED {"rel":"maps_to"}]-(n35),
# (n31)-[:CONNECTED {"rel":"maps_to"}]-(n36),
# (n31)-[:CONNECTED {"rel":"maps_to"}]-(n37),
# (n31)-[:CONNECTED {"rel":"maps_to"}]-(n38),
# (n32)-[:CONNECTED {"rel":"has_control"}]-(n31),
# (n39)-[:CONNECTED {"rel":"maps_to"}]-(n41),
# (n39)-[:CONNECTED {"rel":"maps_to"}]-(n42),
# (n39)-[:CONNECTED {"rel":"maps_to"}]-(n43),
# (n39)-[:CONNECTED {"rel":"maps_to"}]-(n44),
# (n39)-[:CONNECTED {"rel":"maps_to"}]-(n45),
# (n39)-[:CONNECTED {"rel":"maps_to"}]-(n46),
# (n40)-[:CONNECTED {"rel":"has_control"}]-(n39),
# (n47)-[:CONNECTED {"rel":"maps_to"}]-(n49),
# (n47)-[:CONNECTED {"rel":"maps_to"}]-(n50),
# (n47)-[:CONNECTED {"rel":"maps_to"}]-(n51),
# (n47)-[:CONNECTED {"rel":"maps_to"}]-(n52),
# (n47)-[:CONNECTED {"rel":"maps_to"}]-(n53),
# (n47)-[:CONNECTED {"rel":"maps_to"}]-(n54),
# (n48)-[:CONNECTED {"rel":"has_control"}]-(n47),
# (n55)-[:CONNECTED {"rel":"maps_to"}]-(n58),
# (n55)-[:CONNECTED {"rel":"maps_to"}]-(n59),
# (n55)-[:CONNECTED {"rel":"maps_to"}]-(n60),
# (n55)-[:CONNECTED {"rel":"maps_to"}]-(n61),
# (n55)-[:CONNECTED {"rel":"maps_to"}]-(n62),
# (n56)-[:CONNECTED {"rel":"contains"}]-(n57),
# (n56)-[:CONNECTED {"rel":"contains"}]-(n64),
# (n56)-[:CONNECTED {"rel":"contains"}]-(n72),
# (n56)-[:CONNECTED {"rel":"contains"}]-(n79),
# (n57)-[:CONNECTED {"rel":"has_control"}]-(n55),
# (n63)-[:CONNECTED {"rel":"maps_to"}]-(n65),
# (n63)-[:CONNECTED {"rel":"maps_to"}]-(n66),
# (n63)-[:CONNECTED {"rel":"maps_to"}]-(n67),
# (n63)-[:CONNECTED {"rel":"maps_to"}]-(n68),
# (n63)-[:CONNECTED {"rel":"maps_to"}]-(n69),
# (n63)-[:CONNECTED {"rel":"maps_to"}]-(n70),
# (n64)-[:CONNECTED {"rel":"has_control"}]-(n63),
# (n71)-[:CONNECTED {"rel":"maps_to"}]-(n73),
# (n71)-[:CONNECTED {"rel":"maps_to"}]-(n74),
# (n71)-[:CONNECTED {"rel":"maps_to"}]-(n75),
# (n71)-[:CONNECTED {"rel":"maps_to"}]-(n76),
# (n71)-[:CONNECTED {"rel":"maps_to"}]-(n77),
# (n72)-[:CONNECTED {"rel":"has_control"}]-(n71),
# (n78)-[:CONNECTED {"rel":"maps_to"}]-(n80),
# (n78)-[:CONNECTED {"rel":"maps_to"}]-(n81),
# (n78)-[:CONNECTED {"rel":"maps_to"}]-(n82),
# (n78)-[:CONNECTED {"rel":"maps_to"}]-(n83),
# (n78)-[:CONNECTED {"rel":"maps_to"}]-(n62),
# (n79)-[:CONNECTED {"rel":"has_control"}]-(n78),
# (n84)-[:CONNECTED {"rel":"maps_to"}]-(n87),
# (n84)-[:CONNECTED {"rel":"maps_to"}]-(n88),
# (n84)-[:CONNECTED {"rel":"maps_to"}]-(n89),
# (n84)-[:CONNECTED {"rel":"maps_to"}]-(n90),
# (n85)-[:CONNECTED {"rel":"contains"}]-(n86),
# (n85)-[:CONNECTED {"rel":"contains"}]-(n92),
# (n85)-[:CONNECTED {"rel":"contains"}]-(n98),
# (n85)-[:CONNECTED {"rel":"contains"}]-(n104),
# (n85)-[:CONNECTED {"rel":"contains"}]-(n111),
# (n86)-[:CONNECTED {"rel":"has_control"}]-(n84),
# (n91)-[:CONNECTED {"rel":"maps_to"}]-(n93),
# (n91)-[:CONNECTED {"rel":"maps_to"}]-(n94),
# (n91)-[:CONNECTED {"rel":"maps_to"}]-(n95),
# (n91)-[:CONNECTED {"rel":"maps_to"}]-(n96),
# (n92)-[:CONNECTED {"rel":"has_control"}]-(n91),
# (n97)-[:CONNECTED {"rel":"maps_to"}]-(n99),
# (n97)-[:CONNECTED {"rel":"maps_to"}]-(n100),
# (n97)-[:CONNECTED {"rel":"maps_to"}]-(n101),
# (n97)-[:CONNECTED {"rel":"maps_to"}]-(n102),
# (n98)-[:CONNECTED {"rel":"has_control"}]-(n97),
# (n103)-[:CONNECTED {"rel":"maps_to"}]-(n105),
# (n103)-[:CONNECTED {"rel":"maps_to"}]-(n106),
# (n103)-[:CONNECTED {"rel":"maps_to"}]-(n107),
# (n103)-[:CONNECTED {"rel":"maps_to"}]-(n108),
# (n103)-[:CONNECTED {"rel":"maps_to"}]-(n109),
# (n104)-[:CONNECTED {"rel":"has_control"}]-(n103),
# (n110)-[:CONNECTED {"rel":"maps_to"}]-(n112),
# (n110)-[:CONNECTED {"rel":"maps_to"}]-(n113),
# (n110)-[:CONNECTED {"rel":"maps_to"}]-(n114),
# (n110)-[:CONNECTED {"rel":"maps_to"}]-(n115),
# (n110)-[:CONNECTED {"rel":"maps_to"}]-(n90),
# (n110)-[:CONNECTED {"rel":"maps_to"}]-(n96),
# (n111)-[:CONNECTED {"rel":"has_control"}]-(n110),
# (n116)-[:CONNECTED {"rel":"maps_to"}]-(n119),
# (n116)-[:CONNECTED {"rel":"maps_to"}]-(n120),
# (n116)-[:CONNECTED {"rel":"maps_to"}]-(n121),
# (n117)-[:CONNECTED {"rel":"contains"}]-(n118),
# (n117)-[:CONNECTED {"rel":"contains"}]-(n123),
# (n117)-[:CONNECTED {"rel":"contains"}]-(n128),
# (n117)-[:CONNECTED {"rel":"contains"}]-(n132),
# (n117)-[:CONNECTED {"rel":"contains"}]-(n137),
# (n117)-[:CONNECTED {"rel":"contains"}]-(n142),
# (n118)-[:CONNECTED {"rel":"has_control"}]-(n116),
# (n122)-[:CONNECTED {"rel":"maps_to"}]-(n124),
# (n122)-[:CONNECTED {"rel":"maps_to"}]-(n125),
# (n122)-[:CONNECTED {"rel":"maps_to"}]-(n126),
# (n123)-[:CONNECTED {"rel":"has_control"}]-(n122),
# (n127)-[:CONNECTED {"rel":"maps_to"}]-(n129),
# (n127)-[:CONNECTED {"rel":"maps_to"}]-(n120),
# (n127)-[:CONNECTED {"rel":"maps_to"}]-(n130),
# (n128)-[:CONNECTED {"rel":"has_control"}]-(n127),
# (n131)-[:CONNECTED {"rel":"maps_to"}]-(n133),
# (n131)-[:CONNECTED {"rel":"maps_to"}]-(n134),
# (n131)-[:CONNECTED {"rel":"maps_to"}]-(n135),
# (n132)-[:CONNECTED {"rel":"has_control"}]-(n131),
# (n136)-[:CONNECTED {"rel":"maps_to"}]-(n138),
# (n136)-[:CONNECTED {"rel":"maps_to"}]-(n139),
# (n136)-[:CONNECTED {"rel":"maps_to"}]-(n140),
# (n137)-[:CONNECTED {"rel":"has_control"}]-(n136),
# (n141)-[:CONNECTED {"rel":"maps_to"}]-(n143),
# (n141)-[:CONNECTED {"rel":"maps_to"}]-(n144),
# (n141)-[:CONNECTED {"rel":"maps_to"}]-(n145),
# (n142)-[:CONNECTED {"rel":"has_control"}]-(n141),
# (n146)-[:CONNECTED {"rel":"maps_to"}]-(n149),
# (n146)-[:CONNECTED {"rel":"maps_to"}]-(n150),
# (n146)-[:CONNECTED {"rel":"maps_to"}]-(n151),
# (n146)-[:CONNECTED {"rel":"maps_to"}]-(n152),
# (n146)-[:CONNECTED {"rel":"maps_to"}]-(n153),
# (n146)-[:CONNECTED {"rel":"maps_to"}]-(n154),
# (n147)-[:CONNECTED {"rel":"contains"}]-(n148),
# (n147)-[:CONNECTED {"rel":"contains"}]-(n156),
# (n147)-[:CONNECTED {"rel":"contains"}]-(n164),
# (n147)-[:CONNECTED {"rel":"contains"}]-(n172),
# (n147)-[:CONNECTED {"rel":"contains"}]-(n179),
# (n148)-[:CONNECTED {"rel":"has_control"}]-(n146),
# (n155)-[:CONNECTED {"rel":"maps_to"}]-(n157),
# (n155)-[:CONNECTED {"rel":"maps_to"}]-(n158),
# (n155)-[:CONNECTED {"rel":"maps_to"}]-(n159),
# (n155)-[:CONNECTED {"rel":"maps_to"}]-(n160),
# (n155)-[:CONNECTED {"rel":"maps_to"}]-(n161),
# (n155)-[:CONNECTED {"rel":"maps_to"}]-(n162),
# (n156)-[:CONNECTED {"rel":"has_control"}]-(n155),
# (n163)-[:CONNECTED {"rel":"maps_to"}]-(n165),
# (n163)-[:CONNECTED {"rel":"maps_to"}]-(n166),
# (n163)-[:CONNECTED {"rel":"maps_to"}]-(n167),
# (n163)-[:CONNECTED {"rel":"maps_to"}]-(n168),
# (n163)-[:CONNECTED {"rel":"maps_to"}]-(n169),
# (n163)-[:CONNECTED {"rel":"maps_to"}]-(n170),
# (n164)-[:CONNECTED {"rel":"has_control"}]-(n163),
# (n171)-[:CONNECTED {"rel":"maps_to"}]-(n173),
# (n171)-[:CONNECTED {"rel":"maps_to"}]-(n174),
# (n171)-[:CONNECTED {"rel":"maps_to"}]-(n175),
# (n171)-[:CONNECTED {"rel":"maps_to"}]-(n176),
# (n171)-[:CONNECTED {"rel":"maps_to"}]-(n177),
# (n172)-[:CONNECTED {"rel":"has_control"}]-(n171),
# (n178)-[:CONNECTED {"rel":"maps_to"}]-(n180),
# (n178)-[:CONNECTED {"rel":"maps_to"}]-(n181),
# (n178)-[:CONNECTED {"rel":"maps_to"}]-(n182),
# (n178)-[:CONNECTED {"rel":"maps_to"}]-(n183),
# (n178)-[:CONNECTED {"rel":"maps_to"}]-(n184),
# (n179)-[:CONNECTED {"rel":"has_control"}]-(n178),
# (n185)-[:CONNECTED {"rel":"maps_to"}]-(n188),
# (n185)-[:CONNECTED {"rel":"maps_to"}]-(n189),
# (n185)-[:CONNECTED {"rel":"maps_to"}]-(n190),
# (n186)-[:CONNECTED {"rel":"contains"}]-(n187),
# (n186)-[:CONNECTED {"rel":"contains"}]-(n192),
# (n186)-[:CONNECTED {"rel":"contains"}]-(n196),
# (n186)-[:CONNECTED {"rel":"contains"}]-(n200),
# (n187)-[:CONNECTED {"rel":"has_control"}]-(n185),
# (n191)-[:CONNECTED {"rel":"maps_to"}]-(n193),
# (n191)-[:CONNECTED {"rel":"maps_to"}]-(n194),
# (n192)-[:CONNECTED {"rel":"has_control"}]-(n191),
# (n195)-[:CONNECTED {"rel":"maps_to"}]-(n197),
# (n195)-[:CONNECTED {"rel":"maps_to"}]-(n198),
# (n196)-[:CONNECTED {"rel":"has_control"}]-(n195),
# (n199)-[:CONNECTED {"rel":"maps_to"}]-(n201),
# (n199)-[:CONNECTED {"rel":"maps_to"}]-(n202),
# (n200)-[:CONNECTED {"rel":"has_control"}]-(n199),
# (n203)-[:CONNECTED {"rel":"maps_to"}]-(n206),
# (n203)-[:CONNECTED {"rel":"maps_to"}]-(n207),
# (n203)-[:CONNECTED {"rel":"maps_to"}]-(n208),
# (n203)-[:CONNECTED {"rel":"maps_to"}]-(n209),
# (n203)-[:CONNECTED {"rel":"maps_to"}]-(n210),
# (n203)-[:CONNECTED {"rel":"maps_to"}]-(n211),
# (n204)-[:CONNECTED {"rel":"contains"}]-(n205),
# (n204)-[:CONNECTED {"rel":"contains"}]-(n213),
# (n204)-[:CONNECTED {"rel":"contains"}]-(n220),
# (n205)-[:CONNECTED {"rel":"has_control"}]-(n203),
# (n212)-[:CONNECTED {"rel":"maps_to"}]-(n214),
# (n212)-[:CONNECTED {"rel":"maps_to"}]-(n215),
# (n212)-[:CONNECTED {"rel":"maps_to"}]-(n174),
# (n212)-[:CONNECTED {"rel":"maps_to"}]-(n216),
# (n212)-[:CONNECTED {"rel":"maps_to"}]-(n217),
# (n212)-[:CONNECTED {"rel":"maps_to"}]-(n218),
# (n213)-[:CONNECTED {"rel":"has_control"}]-(n212),
# (n219)-[:CONNECTED {"rel":"maps_to"}]-(n221),
# (n219)-[:CONNECTED {"rel":"maps_to"}]-(n222),
# (n219)-[:CONNECTED {"rel":"maps_to"}]-(n223),
# (n219)-[:CONNECTED {"rel":"maps_to"}]-(n224),
# (n219)-[:CONNECTED {"rel":"maps_to"}]-(n225),
# (n219)-[:CONNECTED {"rel":"maps_to"}]-(n226),
# (n220)-[:CONNECTED {"rel":"has_control"}]-(n219),
# (n227)-[:CONNECTED {"rel":"maps_to"}]-(n230),
# (n227)-[:CONNECTED {"rel":"maps_to"}]-(n231),
# (n227)-[:CONNECTED {"rel":"maps_to"}]-(n232),
# (n227)-[:CONNECTED {"rel":"maps_to"}]-(n233),
# (n227)-[:CONNECTED {"rel":"maps_to"}]-(n234),
# (n227)-[:CONNECTED {"rel":"maps_to"}]-(n235),
# (n228)-[:CONNECTED {"rel":"contains"}]-(n229),
# (n228)-[:CONNECTED {"rel":"contains"}]-(n237),
# (n228)-[:CONNECTED {"rel":"contains"}]-(n245),
# (n229)-[:CONNECTED {"rel":"has_control"}]-(n227),
# (n236)-[:CONNECTED {"rel":"maps_to"}]-(n238),
# (n236)-[:CONNECTED {"rel":"maps_to"}]-(n239),
# (n236)-[:CONNECTED {"rel":"maps_to"}]-(n240),
# (n236)-[:CONNECTED {"rel":"maps_to"}]-(n241),
# (n236)-[:CONNECTED {"rel":"maps_to"}]-(n242),
# (n236)-[:CONNECTED {"rel":"maps_to"}]-(n243),
# (n237)-[:CONNECTED {"rel":"has_control"}]-(n236),
# (n244)-[:CONNECTED {"rel":"maps_to"}]-(n246),
# (n244)-[:CONNECTED {"rel":"maps_to"}]-(n247),
# (n244)-[:CONNECTED {"rel":"maps_to"}]-(n248),
# (n244)-[:CONNECTED {"rel":"maps_to"}]-(n249),
# (n244)-[:CONNECTED {"rel":"maps_to"}]-(n250),
# (n244)-[:CONNECTED {"rel":"maps_to"}]-(n251),
# (n245)-[:CONNECTED {"rel":"has_control"}]-(n244),
# (n252)-[:CONNECTED {"rel":"maps_to"}]-(n255),
# (n252)-[:CONNECTED {"rel":"maps_to"}]-(n256),
# (n252)-[:CONNECTED {"rel":"maps_to"}]-(n257),
# (n252)-[:CONNECTED {"rel":"maps_to"}]-(n258),
# (n252)-[:CONNECTED {"rel":"maps_to"}]-(n259),
# (n252)-[:CONNECTED {"rel":"maps_to"}]-(n260),
# (n253)-[:CONNECTED {"rel":"contains"}]-(n254),
# (n253)-[:CONNECTED {"rel":"contains"}]-(n262),
# (n254)-[:CONNECTED {"rel":"has_control"}]-(n252),
# (n261)-[:CONNECTED {"rel":"maps_to"}]-(n263),
# (n261)-[:CONNECTED {"rel":"maps_to"}]-(n264),
# (n261)-[:CONNECTED {"rel":"maps_to"}]-(n265),
# (n261)-[:CONNECTED {"rel":"maps_to"}]-(n266),
# (n261)-[:CONNECTED {"rel":"maps_to"}]-(n267),
# (n261)-[:CONNECTED {"rel":"maps_to"}]-(n268),
# (n262)-[:CONNECTED {"rel":"has_control"}]-(n261),
# (n269)-[:CONNECTED {"rel":"maps_to"}]-(n272),
# (n269)-[:CONNECTED {"rel":"maps_to"}]-(n273),
# (n269)-[:CONNECTED {"rel":"maps_to"}]-(n274),
# (n269)-[:CONNECTED {"rel":"maps_to"}]-(n275),
# (n269)-[:CONNECTED {"rel":"maps_to"}]-(n276),
# (n269)-[:CONNECTED {"rel":"maps_to"}]-(n277),
# (n270)-[:CONNECTED {"rel":"contains"}]-(n271),
# (n270)-[:CONNECTED {"rel":"contains"}]-(n279),
# (n271)-[:CONNECTED {"rel":"has_control"}]-(n269),
# (n278)-[:CONNECTED {"rel":"maps_to"}]-(n280),
# (n278)-[:CONNECTED {"rel":"maps_to"}]-(n281),
# (n278)-[:CONNECTED {"rel":"maps_to"}]-(n282),
# (n278)-[:CONNECTED {"rel":"maps_to"}]-(n283),
# (n278)-[:CONNECTED {"rel":"maps_to"}]-(n284),
# (n278)-[:CONNECTED {"rel":"maps_to"}]-(n277),
# (n279)-[:CONNECTED {"rel":"has_control"}]-(n278),
# (n285)-[:CONNECTED {"rel":"maps_to"}]-(n288),
# (n285)-[:CONNECTED {"rel":"maps_to"}]-(n289),
# (n285)-[:CONNECTED {"rel":"maps_to"}]-(n290),
# (n285)-[:CONNECTED {"rel":"maps_to"}]-(n291),
# (n285)-[:CONNECTED {"rel":"maps_to"}]-(n292),
# (n285)-[:CONNECTED {"rel":"maps_to"}]-(n293),
# (n286)-[:CONNECTED {"rel":"contains"}]-(n287),
# (n286)-[:CONNECTED {"rel":"contains"}]-(n295),
# (n286)-[:CONNECTED {"rel":"contains"}]-(n301),
# (n287)-[:CONNECTED {"rel":"has_control"}]-(n285),
# (n294)-[:CONNECTED {"rel":"maps_to"}]-(n288),
# (n294)-[:CONNECTED {"rel":"maps_to"}]-(n296),
# (n294)-[:CONNECTED {"rel":"maps_to"}]-(n297),
# (n294)-[:CONNECTED {"rel":"maps_to"}]-(n298),
# (n294)-[:CONNECTED {"rel":"maps_to"}]-(n292),
# (n294)-[:CONNECTED {"rel":"maps_to"}]-(n299),
# (n295)-[:CONNECTED {"rel":"has_control"}]-(n294),
# (n300)-[:CONNECTED {"rel":"maps_to"}]-(n288),
# (n300)-[:CONNECTED {"rel":"maps_to"}]-(n302),
# (n300)-[:CONNECTED {"rel":"maps_to"}]-(n303),
# (n300)-[:CONNECTED {"rel":"maps_to"}]-(n291),
# (n300)-[:CONNECTED {"rel":"maps_to"}]-(n292),
# (n300)-[:CONNECTED {"rel":"maps_to"}]-(n304),
# (n301)-[:CONNECTED {"rel":"has_control"}]-(n300)
# ****************************************************************************************************

# %%
# %%time

# Run CREATE command
client.query(create_command)

# Commit the change
client.query("COMMIT")
client.query("CHANGE SUBMIT")

# Checkout into main
client.checkout()
# Out:
# CPU times: user 1.96 ms, sys: 846 μs, total: 2.8 ms
# Wall time: 150 ms

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2>
#         Visualize your graph in TuringDB Graph Visualizer ! Now that your instance is running:
#     </h2>
#     <h3>
#         <ul>
#             <li>Go to <a href="https://console.turingdb.ai/databases">TuringDB Console - Database Instances</a></li>
#             <li>In your current instance panel, click on "Open Visualizer" button</li>
#             <li>Visualizer opens, now you can choose your graph in the dropdown menu at the top-right corner</li>
#         </ul>
#         You can then play with your graph and visualize the nodes you want !
#     </h3>
# </div>

# %% [markdown]
# # Query TuringDB

# %% [markdown]
# ## Use metaqueries to have insight on graph overall structure
#
# <h3>
#     To learn more about 📮 Metaqueries, please check TuringDB documentation on this <a href="https://turingdb.mintlify.app/query/cypher_subset#%F0%9F%93%AE-metaqueries">link</a>
# </h3>

# %%
# %%time

# CALL PROPERTIES() - returns a column of all the different node and edge properties and their types in the database
command = """
CALL PROPERTIES()
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = ["Property_ID", "Property_name", "Property_type"]
    display(df)
# Out:
#    Property_ID Property_name Property_type
# 0            0            id        String
# 1            1          type        String
# 2            2     statement        String
# 3            3        domain        String
# 4            4        master        String
# 5            5         topic        String
# 6            6          name        String
# 7            7      standard        String
# 8            8     reference        String
# 9            9           rel        String
# CPU times: user 4.87 ms, sys: 0 ns, total: 4.87 ms
# Wall time: 4.34 ms

# %%
# %%time

# CALL LABELS () - returns a column of all the different node labels
command = """
CALL LABELS()
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = ["Node_type_ID", "Node_label"]
    display(df)
# Out:
#    Node_type_ID Node_label
# 0             0    Control
# 1             1     Domain
# 2             2      Topic
# 3             3   Standard
# CPU times: user 2.27 ms, sys: 887 μs, total: 3.15 ms
# Wall time: 2.72 ms

# %%
# %%time

# CALL EDGETYPES() - returns a column of all the different edge types (edge equivalent of node labels)
command = """
CALL EDGETYPES()
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = ["Edge_type_ID", "Edge_label"]
    display(df)
# Out:
#    Edge_type_ID Edge_label
# 0             0  CONNECTED
# CPU times: user 2.18 ms, sys: 872 μs, total: 3.05 ms
# Wall time: 2.5 ms

# %%
# %%time

# CALL LABELSETS() - returns a two columns describing combinations of node labels
command = """
CALL LABELSETS()
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = ["Node_type_ID", "Node_label"]
    display(df)
# Out:
#    Node_type_ID Node_label
# 0             0    Control
# 1             1     Domain
# 2             2      Topic
# 3             3   Standard
# CPU times: user 2.11 ms, sys: 859 μs, total: 2.97 ms
# Wall time: 2.57 ms

# %% [markdown]
# ## Simple queries

# %%
# %%time

# Match all edges and return them
command = """
MATCH (n)-[e]-(m)
RETURN n.id, e, m.id
"""
df = client.query(command)
if df.empty:
    print("No result found")
else:
    df.columns = get_return_statements(command)
    display(df)
# Out:
#                                                   n.id    e  \
# 0                                           control_34    0
# 1                                           control_34    1
# 2                                           control_34    2
# 3                                           control_34    3
# 4                                           control_34    4
# ..                                                 ...  ...
# 299       topic_Transparency, Disclosure and Reporting  299
# 300                                   topic_Robustness  300
# 301                                topic_Data Security  301
# 302  topic_Security Governance, Architecture and En...  302
# 303            topic_Privacy Compliance and Monitoring  303
#
#                                                   m.id
# 0                          std_ISO27701_12.2.2 A.7.4.3
# 1               std_EU_AI_ACT_26.5 72.1 72.2 72.3 72.4
# 2    std_NIST_RMF_Measure 1.2 Measure 2.4 Manage 2....
# 3                       std_SOC2_CC4.1 CC4.2 A1.1 A1.2
# 4     std_ISO27001_8.1-8.3 A.12.3 A.12.6 A.17.1 A.17.2
# ..                                                 ...
# 299                                          control_8
# 300                                         control_24
# 301                                         control_19
# 302                                         control_16
# 303                                         control_29
#
# [304 rows x 3 columns]
# CPU times: user 4.44 ms, sys: 72 μs, total: 4.52 ms
# Wall time: 4.1 ms

# %% [markdown]
# # Load the embedding model

# %%
# %%time

# This will convert text to vectors
model = SentenceTransformer('paraphrase-MiniLM-L3-v2')
print(f"✓ Model loaded: {model.get_sentence_embedding_dimension()} dimensions")
# Out:
# ✓ Model loaded: 384 dimensions
# CPU times: user 177 ms, sys: 24.4 ms, total: 202 ms
# Wall time: 1.42 s

# %% [markdown]
# # Build vector index on the graph

# %% [markdown]
# ## Vector Search Implementation - Dense (semantic) search

# %% [markdown]
# #### How It Works
#
# Each control is converted to a **384-dimensional vector** using a pre-trained language model (`paraphrase-MiniLM-L3-v2`).
#
# **Search process:**
# 1. Convert user query to vector
# 2. Calculate cosine similarity with all control vectors
# 3. Rank by similarity score (0-1)
# 4. Return top-k most relevant controls
#
# #### Why Vectors?
#
# - **Semantic understanding**: "data protection" matches "privacy safeguards"
# - **Handles synonyms**: "AI governance" finds "artificial intelligence oversight"
# - **No keyword dependency**: Works even without exact term matches

# %% [markdown]
# ### Use the three different approaches

# %%
# %%time

# Build different versions
node_only = build_node_only_embeddings(G, model)  # Node-only embeddings
lightweight = build_context_enriched_embeddings(G, model, strategy='lightweight')  # Context-enriched embeddings
smart = build_smart_enriched_embeddings(G, model)  # Type-specific context enrichment

print("\n" + "="*80 + "\n")

# Compare what gets encoded for a control node
control_id = 'control_0'

print("NODE-ONLY TEXT:")
print(node_only[1][control_id])
print("\n" + "="*80 + "\n")

print("SMART ENRICHED TEXT:")
print(smart[1][control_id])
print("\n" + "="*80 + "\n")
# Out:
# ✓ Vector index built using node-only embeddings approach: 305 vectors
# ✓ Vector index built using context-enriched embeddings approach (strategy lightweight): 305 vectors
# ✓ Vector index built using type-specific context enrichment approach: 305 vectors
#
# ================================================================================
#
# NODE-ONLY TEXT:
# The organisation's executive leadership shall establish, document, and maintain formal accountability for AI governance through approved policies that align with organisational objectives and values. These policies shall be reviewed at planned intervals by executive leadership to ensure continued effectiveness and relevance. Executive leadership shall demonstrate active engagement in AI risk decisions and maintain ultimate accountability for the organisation's AI systems.
#
# ================================================================================
#
# SMART ENRICHED TEXT:
# The organisation's executive leadership shall establish, document, and maintain formal accountability for AI governance through approved policies that align with organisational objectives and values. These policies shall be reviewed at planned intervals by executive leadership to ensure continued effectiveness and relevance. Executive leadership shall demonstrate active engagement in AI risk decisions and maintain ultimate accountability for the organisation's AI systems.. Topic: Executive Commitment and Accountability. Domain: Governance & Leadership. Standards: ISO42001 4.1 5.1 5.2 9.3 A.2.2 A.2.3 A.2.4, ISO27001 5.1 5.2 9.3 A.5.1 A.5.2, ISO27701 6.1.1 6.1.2, EU_AI_ACT 4.1, NIST_RMF Govern 1.1 Govern 2.3 Govern 3.1, SOC2 CC.1.1 CC.1.2 CC.1.3 CC.1.4 CC.1.5 CC.5.3
#
# ================================================================================
#
# CPU times: user 13.7 s, sys: 830 ms, total: 14.5 s
# Wall time: 901 ms

# %% [markdown]
# ## Vector Search Implementation - Sparse (keyword) search

# %%
# %%time

# Build sparse embeddings
sparse_vectors, node_texts, sparse_vectorizer = build_sparse_embeddings(
    G=G,
    max_features=500,
    ngram_range=(1, 2)
)
# Out:
# Building sparse index (TF-IDF)...
# ✓ Sparse index built: 305 vectors
#   Vocabulary size: 500
#   Sample terms: ['access', 'accessible', 'accountability', 'actions', 'activities', 'address', 'address identified', 'affected', 'affected individuals', 'agreements', 'ai', 'ai development', 'ai driven', 'ai governance', 'ai impacts', 'ai lifecycle', 'ai systems', 'align', 'align organisational', 'alignment']
# CPU times: user 19.1 ms, sys: 114 μs, total: 19.2 ms
# Wall time: 18.4 ms

# %% [markdown]
# ## Node2Vec

# %%
# %%time

# Build structural embeddings
structural_vectors = build_node2vec_embeddings(G, dimensions=384)
# Out:
# Training Node2Vec on graph structure...
# /home/dev/turingdb-graphrag/.venv/lib/python3.13/site-packages/node2vec/edges.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /home/dev/turingdb-graphrag/.venv/lib/python3.13/site-packages/node2vec/edges.py:6: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# ✓ Node2Vec trained: 305 structural vectors
# CPU times: user 4.9 s, sys: 1.9 s, total: 6.81 s
# Wall time: 6.33 s

# %%
structural_vectors[control_id].shape
# Out:
# (384,)

# %% [markdown]
# # Search capabilities

# %% [markdown]
# ## Vector Search Implementation - Dense (semantic) search
#
# Find controls relevant to any natural language query:
#
# ```python
# results = search("data privacy protection", k=5)
# ```
#
# **Use cases:**
# - Exploratory research: "What controls cover AI model governance?"
# - Concept-based lookup: "security monitoring requirements"
# - Gap analysis: "What's missing in our risk management?"

# %%
# Choose most relevant approach
node_vectors = smart[0]
node_texts = smart[1]

# %% [markdown]
# ### Query

# %%
# %%time

# Example 1: Find controls about data privacy
query = "data privacy protection"
results = dense_search(
    query=query,
    node_vectors=node_vectors,
    node_texts=node_texts,
    G=G,
    model=model,
    k=3,
    #node_type='control'
)
print(f"Query: '{query}'")
print_results(results)
# Out:
# Query: 'data privacy protection'
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.7615
#    Node: domain_Privacy
#    Type: domain
#    Text: Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Management, Privacy Compliance and Monitoring, Privacy-Enhancing Technologies and Mechanisms...
#
# 2. Similarity: 0.6742
#    Node: topic_Privacy-Enhancing Technologies and Mechanisms
#    Type: topic
#    Text: Topic: Privacy-Enhancing Technologies and Mechanisms. Domain: Privacy. Examples: The organisation shall implement appropriate technical mechanisms and privacy-en...
#
# 3. Similarity: 0.6605
#    Node: control_30
#    Type: control
#    Text: The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies in AI systems to protect personal data and ensure privacy by default. This includes implementing en...
#    Domain: Privacy
#    Topic: Privacy-Enhancing Technologies and Mechanisms
# CPU times: user 79.8 ms, sys: 2.76 ms, total: 82.6 ms
# Wall time: 7.41 ms

# %%
# %%time

# Other examples
# Try different queries
queries = [
    "AI model governance",
    "risk management controls",
    "security monitoring requirements",
    "data subject rights"
]

for query in queries:
    print(f"\n{'='*80}")
    print(f"QUERY: '{query}'")
    print('='*80)
    results = dense_search(
        query="data privacy protection",
        node_vectors=node_vectors,
        node_texts=node_texts,
        G=G,
        model=model,
        k=3,
        #node_type='control'
    )
    print_results(results)
# Out:
# ================================================================================
# QUERY: 'AI model governance'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.7615
#    Node: domain_Privacy
#    Type: domain
#    Text: Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Management, Privacy Compliance and Monitoring, Privacy-Enhancing Technologies and Mechanisms...
#
# 2. Similarity: 0.6742
#    Node: topic_Privacy-Enhancing Technologies and Mechanisms
#    Type: topic
#    Text: Topic: Privacy-Enhancing Technologies and Mechanisms. Domain: Privacy. Examples: The organisation shall implement appropriate technical mechanisms and privacy-en...
#
# 3. Similarity: 0.6605
#    Node: control_30
#    Type: control
#    Text: The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies in AI systems to protect personal data and ensure privacy by default. This includes implementing en...
#    Domain: Privacy
#    Topic: Privacy-Enhancing Technologies and Mechanisms
#
# ================================================================================
# QUERY: 'risk management controls'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.7615
#    Node: domain_Privacy
#    Type: domain
#    Text: Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Management, Privacy Compliance and Monitoring, Privacy-Enhancing Technologies and Mechanisms...
#
# 2. Similarity: 0.6742
#    Node: topic_Privacy-Enhancing Technologies and Mechanisms
#    Type: topic
#    Text: Topic: Privacy-Enhancing Technologies and Mechanisms. Domain: Privacy. Examples: The organisation shall implement appropriate technical mechanisms and privacy-en...
#
# 3. Similarity: 0.6605
#    Node: control_30
#    Type: control
#    Text: The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies in AI systems to protect personal data and ensure privacy by default. This includes implementing en...
#    Domain: Privacy
#    Topic: Privacy-Enhancing Technologies and Mechanisms
#
# ================================================================================
# QUERY: 'security monitoring requirements'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.7615
#    Node: domain_Privacy
#    Type: domain
#    Text: Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Management, Privacy Compliance and Monitoring, Privacy-Enhancing Technologies and Mechanisms...
#
# 2. Similarity: 0.6742
#    Node: topic_Privacy-Enhancing Technologies and Mechanisms
#    Type: topic
#    Text: Topic: Privacy-Enhancing Technologies and Mechanisms. Domain: Privacy. Examples: The organisation shall implement appropriate technical mechanisms and privacy-en...
#
# 3. Similarity: 0.6605
#    Node: control_30
#    Type: control
#    Text: The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies in AI systems to protect personal data and ensure privacy by default. This includes implementing en...
#    Domain: Privacy
#    Topic: Privacy-Enhancing Technologies and Mechanisms
#
# ================================================================================
# QUERY: 'data subject rights'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.7615
#    Node: domain_Privacy
#    Type: domain
#    Text: Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Management, Privacy Compliance and Monitoring, Privacy-Enhancing Technologies and Mechanisms...
#
# 2. Similarity: 0.6742
#    Node: topic_Privacy-Enhancing Technologies and Mechanisms
#    Type: topic
#    Text: Topic: Privacy-Enhancing Technologies and Mechanisms. Domain: Privacy. Examples: The organisation shall implement appropriate technical mechanisms and privacy-en...
#
# 3. Similarity: 0.6605
#    Node: control_30
#    Type: control
#    Text: The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies in AI systems to protect personal data and ensure privacy by default. This includes implementing en...
#    Domain: Privacy
#    Topic: Privacy-Enhancing Technologies and Mechanisms
# CPU times: user 342 ms, sys: 0 ns, total: 342 ms
# Wall time: 22.9 ms

# %% [markdown]
# ## Vector Search Implementation - Sparse (keyword) search

# %%
# %%time

# Example: Find controls about data privacy
query = "data privacy protection"
results = sparse_search(
    query=query,
    sparse_vectors=sparse_vectors,
    sparse_vectorizer=sparse_vectorizer,
    node_texts=node_texts,
    G=G,
    k=3,
    node_type='control'
)
print(f"Query: '{query}'")
print_results(results)

# Try different queries
queries = [
    "AI model governance",
    "risk management controls",
    "security monitoring requirements",
    "data subject rights"
]

for query in queries:
    print(f"\n{'='*80}")
    print(f"QUERY: '{query}'")
    print('='*80)
    results = sparse_search(
        query=query,
        sparse_vectors=sparse_vectors,
        sparse_vectorizer=sparse_vectorizer,
        node_texts=node_texts,
        G=G,
        k=3,
        node_type='control'
    )
    print_results(results)
# Out:
# Query: 'data privacy protection'
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.4642
#    Node: control_27
#    Type: control
#    Text: The organisation shall implement privacy by design principles in all AI systems, ensuring privacy considerations are embedded from initial planning through system retirement. This includes establishin...
#    Domain: Privacy
#    Topic: Privacy by Design and Governance
#
# 2. Similarity: 0.4379
#    Node: control_30
#    Type: control
#    Text: The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies in AI systems to protect personal data and ensure privacy by default. This includes implementing en...
#    Domain: Privacy
#    Topic: Privacy-Enhancing Technologies and Mechanisms
#
# 3. Similarity: 0.3954
#    Node: control_29
#    Type: control
#    Text: The organisation shall establish processes to monitor compliance with privacy requirements, detect and respond to privacy incidents, and ensure continuous improvement of privacy controls. This include...
#    Domain: Privacy
#    Topic: Privacy Compliance and Monitoring
#
# ================================================================================
# QUERY: 'AI model governance'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.3150
#    Node: control_1
#    Type: control
#    Text: The organisation shall define, document, and maintain clear roles and responsibilities for AI governance, ensuring appropriate segregation of duties and allocation of resources. These roles shall be s...
#    Domain: Governance & Leadership
#    Topic: Roles, Responsibilities & Resources
#
# 2. Similarity: 0.2186
#    Node: control_39
#    Type: control
#    Text: The organisation shall ensure AI systems are designed and operated with appropriate transparency, enabling users and affected individuals to understand when they are interacting with AI, how the AI sy...
#    Domain: Transparency & Communication
#    Topic: AI System Transparency
#
# 3. Similarity: 0.2032
#    Node: control_0
#    Type: control
#    Text: The organisation's executive leadership shall establish, document, and maintain formal accountability for AI governance through approved policies that align with organisational objectives and values. ...
#    Domain: Governance & Leadership
#    Topic: Executive Commitment and Accountability
#
# ================================================================================
# QUERY: 'risk management controls'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.4661
#    Node: control_3
#    Type: control
#    Text: The organisation shall establish, document, and maintain a comprehensive risk management system covering the entire AI lifecycle. This system shall define clear roles, responsibilities, and processes ...
#    Domain: Risk Management
#    Topic: Risk Management Framework and Governance
#
# 2. Similarity: 0.2708
#    Node: control_5
#    Type: control
#    Text: The organisation shall implement appropriate technical and organisational measures to address identified risks, ensuring controls are proportionate to risk levels and organisational risk tolerance. Ri...
#    Domain: Risk Management
#    Topic: Risk Treatment and Control Implementation
#
# 3. Similarity: 0.2205
#    Node: control_16
#    Type: control
#    Text: The organisation shall establish and maintain a comprehensive security governance framework that encompasses security risk management, security policies, standards, and architectures that guide the im...
#    Domain: Security
#    Topic: Security Governance, Architecture and Engineering
#
# ================================================================================
# QUERY: 'security monitoring requirements'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.4978
#    Node: control_16
#    Type: control
#    Text: The organisation shall establish and maintain a comprehensive security governance framework that encompasses security risk management, security policies, standards, and architectures that guide the im...
#    Domain: Security
#    Topic: Security Governance, Architecture and Engineering
#
# 2. Similarity: 0.3035
#    Node: control_38
#    Type: control
#    Text: The organisation shall implement comprehensive processes to identify, assess, manage, and monitor risks associated with third-party AI suppliers and service providers throughout the engagement lifecyc...
#    Domain: Third Party & Supply Chain
#    Topic: Supplier Risk Management
#
# 3. Similarity: 0.2056
#    Node: control_34
#    Type: control
#    Text: The organisation shall implement continuous monitoring of AI system performance and behavior in production environments. This includes automated monitoring of key performance indicators, tracking of s...
#    Domain: Operational Monitoring
#    Topic: System Performance Monitoring
#
# ================================================================================
# QUERY: 'data subject rights'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.3813
#    Node: control_28
#    Type: control
#    Text: The organisation shall implement operational processes for the responsible collection, use, storage, and disposal of personal data in AI systems. This includes maintaining data inventories, implementi...
#    Domain: Privacy
#    Topic: Personal Data Management
#
# 2. Similarity: 0.2733
#    Node: control_11
#    Type: control
#    Text: The organisation shall establish and maintain comprehensive data governance processes ensuring high-quality data throughout the AI system lifecycle. This shall include documented requirements and proc...
#    Domain: System, Data and Model Lifecycle
#    Topic: Data Quality and Governance
#
# 3. Similarity: 0.2237
#    Node: control_19
#    Type: control
#    Text: The organisation shall protect data throughout its lifecycle using appropriate technical and procedural controls, including classification, encryption, and secure handling procedures. This encompasses...
#    Domain: Security
#    Topic: Data Security
# CPU times: user 540 ms, sys: 6.62 ms, total: 547 ms
# Wall time: 533 ms

# %% [markdown]
# ## Hybrid search: Best of Both Worlds

# %% [markdown]
# ### The Problem
#
# - **Dense (semantic) search**: Great for concepts, misses exact terms
# - **Sparse (keyword) search**: Finds exact matches, misses semantics
#
# ### The Solution
#
# **Hybrid search** combines both approaches:
#
# ```
# final_score = α × semantic_score + (1-α) × keyword_score
# ```
#
# ### Alpha Parameter Guide
#
# | Alpha | Behavior | Best For |
# |-------|----------|----------|
# | 1.0 | Pure semantic | Conceptual queries |
# | 0.7 | Favor semantics | General use (recommended) |
# | 0.5 | Balanced | Mixed queries |
# | 0.3 | Favor keywords | Technical lookups |
# | 0.0 | Pure keywords | Exact term matching |
#
# ### When to Use What
#
# **Dense (α=1.0)**
# - Query: "What covers security?"
# - Finds: Controls about protection, safeguards, defense
#
# **Sparse (α=0.0)**
# - Query: "ISO27001 A.8.24"
# - Finds: Exact standard reference
#
# **Hybrid (α=0.7)**
# - Query: "NIST risk management frameworks"
# - Finds: Both NIST references AND risk-related controls

# %% [markdown]
# ### Query

# %%
# %%time

# Example: Find controls about data privacy
query = "data privacy protection"
results = hybrid_search(
    query=query,
    node_vectors=node_vectors,
    node_texts=node_texts,
    G=G,
    sparse_vectors=sparse_vectors,
    sparse_vectorizer=sparse_vectorizer,
    model=model,
    k=3,
    alpha=0.7,  # 70% semantic, 30% keywords
    node_type='control'
)
print(f"Query: '{query}'")
print_results(results)

# Try different queries
queries = [
    "AI model governance",
    "risk management controls",
    "security monitoring requirements",
    "data subject rights"
]

for query in queries:
    print(f"\n{'='*80}")
    print(f"QUERY: '{query}'")
    print('='*80)
    results = hybrid_search(
        query=query,
        node_vectors=node_vectors,
        node_texts=node_texts,
        G=G,
        sparse_vectors=sparse_vectors,
        sparse_vectorizer=sparse_vectorizer,
        model=model,
        k=3,
        alpha=0.7,
        node_type='control'
    )
    print_results(results)
# Out:
# Query: 'data privacy protection'
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.9794
#    Node: control_30
#    Type: control
#    Text: The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies in AI systems to protect personal data and ensure privacy by default. This includes implementing en...
#    Domain: Privacy
#    Topic: Privacy-Enhancing Technologies and Mechanisms
#
# 2. Similarity: 0.8324
#    Node: control_27
#    Type: control
#    Text: The organisation shall implement privacy by design principles in all AI systems, ensuring privacy considerations are embedded from initial planning through system retirement. This includes establishin...
#    Domain: Privacy
#    Topic: Privacy by Design and Governance
#
# 3. Similarity: 0.7496
#    Node: control_29
#    Type: control
#    Text: The organisation shall establish processes to monitor compliance with privacy requirements, detect and respond to privacy incidents, and ensure continuous improvement of privacy controls. This include...
#    Domain: Privacy
#    Topic: Privacy Compliance and Monitoring
#
# ================================================================================
# QUERY: 'AI model governance'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 1.0000
#    Node: control_1
#    Type: control
#    Text: The organisation shall define, document, and maintain clear roles and responsibilities for AI governance, ensuring appropriate segregation of duties and allocation of resources. These roles shall be s...
#    Domain: Governance & Leadership
#    Topic: Roles, Responsibilities & Resources
#
# 2. Similarity: 0.5088
#    Node: control_25
#    Type: control
#    Text: The organisation shall ensure AI systems' decisions and outputs can be appropriately explained and interpreted by relevant stakeholders. This includes maintaining comprehensive documentation of system...
#    Domain: Safe Responsible AI
#    Topic: Explainability and Interpretability
#
# 3. Similarity: 0.4503
#    Node: control_39
#    Type: control
#    Text: The organisation shall ensure AI systems are designed and operated with appropriate transparency, enabling users and affected individuals to understand when they are interacting with AI, how the AI sy...
#    Domain: Transparency & Communication
#    Topic: AI System Transparency
#
# ================================================================================
# QUERY: 'risk management controls'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.8548
#    Node: control_3
#    Type: control
#    Text: The organisation shall establish, document, and maintain a comprehensive risk management system covering the entire AI lifecycle. This system shall define clear roles, responsibilities, and processes ...
#    Domain: Risk Management
#    Topic: Risk Management Framework and Governance
#
# 2. Similarity: 0.8500
#    Node: control_5
#    Type: control
#    Text: The organisation shall implement appropriate technical and organisational measures to address identified risks, ensuring controls are proportionate to risk levels and organisational risk tolerance. Ri...
#    Domain: Risk Management
#    Topic: Risk Treatment and Control Implementation
#
# 3. Similarity: 0.4811
#    Node: control_6
#    Type: control
#    Text: The organisation shall implement continuous monitoring processes to track the effectiveness of risk controls and identify emerging risks throughout the AI lifecycle. This shall include mechanisms for ...
#    Domain: Risk Management
#    Topic: Risk Monitoring and Response
#
# ================================================================================
# QUERY: 'security monitoring requirements'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 0.7000
#    Node: control_33
#    Type: control
#    Text: The organisation shall conduct regular testing of AI system safety and security controls, including assessment of cybersecurity measures, resilience against attacks, and ability to fail safely. Testin...
#    Domain: Assurance and Audit
#    Topic: Safety and Security Validation
#
# 2. Similarity: 0.6021
#    Node: control_16
#    Type: control
#    Text: The organisation shall establish and maintain a comprehensive security governance framework that encompasses security risk management, security policies, standards, and architectures that guide the im...
#    Domain: Security
#    Topic: Security Governance, Architecture and Engineering
#
# 3. Similarity: 0.4447
#    Node: control_21
#    Type: control
#    Text: The organisation shall implement and maintain comprehensive physical security controls to protect information assets, including facilities, equipment, and supporting infrastructure from unauthorised a...
#    Domain: Security
#    Topic: Physical Security
#
# ================================================================================
# QUERY: 'data subject rights'
# ================================================================================
#
# Found 3 results:
# ================================================================================
#
# 1. Similarity: 1.0000
#    Node: control_28
#    Type: control
#    Text: The organisation shall implement operational processes for the responsible collection, use, storage, and disposal of personal data in AI systems. This includes maintaining data inventories, implementi...
#    Domain: Privacy
#    Topic: Personal Data Management
#
# 2. Similarity: 0.5466
#    Node: control_11
#    Type: control
#    Text: The organisation shall establish and maintain comprehensive data governance processes ensuring high-quality data throughout the AI system lifecycle. This shall include documented requirements and proc...
#    Domain: System, Data and Model Lifecycle
#    Topic: Data Quality and Governance
#
# 3. Similarity: 0.5361
#    Node: control_19
#    Type: control
#    Text: The organisation shall protect data throughout its lifecycle using appropriate technical and procedural controls, including classification, encryption, and secure handling procedures. This encompasses...
#    Domain: Security
#    Topic: Data Security
# CPU times: user 1.19 s, sys: 0 ns, total: 1.19 s
# Wall time: 512 ms

# %% [markdown]
# ## Compare Dense vs Sparse vs Hybrid

# %%
# %%time

# Limit results to specific node type (all node types by default)
node_type = None # "control"
k = 5
alpha = 0.6

# Example 1: Query with specific standard ID (sparse should win)
compare_search_methods(
    query="ISO27001 controls",
    node_vectors=node_vectors,
    node_texts=node_texts,
    G=G,
    sparse_vectors=sparse_vectors,
    sparse_vectorizer=sparse_vectorizer,
    model=model,
    k=k,
    alpha=alpha
)

# Example 2: Conceptual query (dense should win)
compare_search_methods(
    query="protecting sensitive information",
    node_vectors=node_vectors,
    node_texts=node_texts,
    G=G,
    sparse_vectors=sparse_vectors,
    sparse_vectorizer=sparse_vectorizer,
    model=model,
    k=k,
    alpha=alpha
)

# Example 3: Mixed query (hybrid should win)
compare_search_methods(
    query="NIST risk management frameworks",
    node_vectors=node_vectors,
    node_texts=node_texts,
    G=G,
    sparse_vectors=sparse_vectors,
    sparse_vectorizer=sparse_vectorizer,
    model=model,
    k=k,
    alpha=alpha
)
# Out:
# ================================================================================
# QUERY: 'ISO27001 controls'
# ================================================================================
#
# 1. DENSE ONLY (Semantic):
# --------------------------------------------------------------------------------
# 1. 0.408 | The organisation shall implement and maintain comprehensive physical security controls to protect in...
# 2. 0.391 | The organisation shall implement mechanisms for meaningful human oversight of AI systems, ensuring h...
# 3. 0.390 | The organisation shall implement appropriate technical and organisational measures to address identi...
#
# 2. SPARSE ONLY (Keywords):
# --------------------------------------------------------------------------------
# 1. 0.211 | The organisation shall implement and maintain comprehensive physical security controls to protect in...
# 2. 0.195 | The organisation shall conduct regular testing of AI system safety and security controls, including ...
# 3. 0.150 | The organisation shall implement and maintain comprehensive network security controls to protect aga...
#
# 3. HYBRID (alpha=0.6):
# --------------------------------------------------------------------------------
# 1. 1.000 (D:1.00/S:1.00) | The organisation shall implement and maintain comprehensive physical security controls to protect in...
# 2. 0.703 (D:0.85/S:0.49) | The organisation shall implement appropriate technical and organisational measures to address identi...
# 3. 0.511 (D:0.85/S:0.00) | The organisation shall implement mechanisms for meaningful human oversight of AI systems, ensuring h...
#
# ================================================================================
# QUERY: 'protecting sensitive information'
# ================================================================================
#
# 1. DENSE ONLY (Semantic):
# --------------------------------------------------------------------------------
# 1. 0.534 | The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies...
# 2. 0.514 | The organisation shall implement and maintain comprehensive physical security controls to protect in...
# 3. 0.477 | The organisation shall implement and maintain comprehensive network security controls to protect aga...
#
# 2. SPARSE ONLY (Keywords):
# --------------------------------------------------------------------------------
# 1. 0.169 | The organisation shall establish clear accountability for AI systems when working with third parties...
# 2. 0.138 | The organisation shall implement and maintain comprehensive physical security controls to protect in...
# 3. 0.094 | The organisation shall implement operational processes for the responsible collection, use, storage,...
#
# 3. HYBRID (alpha=0.6):
# --------------------------------------------------------------------------------
# 1. 0.853 (D:0.88/S:0.81) | The organisation shall implement and maintain comprehensive physical security controls to protect in...
# 2. 0.600 (D:1.00/S:0.00) | The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies...
# 3. 0.472 (D:0.42/S:0.56) | The organisation shall implement operational processes for the responsible collection, use, storage,...
#
# ================================================================================
# QUERY: 'NIST risk management frameworks'
# ================================================================================
#
# 1. DENSE ONLY (Semantic):
# --------------------------------------------------------------------------------
# 1. 0.532 | The organisation shall establish, document, and maintain a comprehensive risk management system cove...
# 2. 0.510 | The organisation shall implement appropriate technical and organisational measures to address identi...
# 3. 0.434 | The organisation shall implement continuous monitoring processes to track the effectiveness of risk ...
#
# 2. SPARSE ONLY (Keywords):
# --------------------------------------------------------------------------------
# 1. 0.534 | The organisation shall establish, document, and maintain a comprehensive risk management system cove...
# 2. 0.253 | The organisation shall implement appropriate technical and organisational measures to address identi...
# 3. 0.193 | The organisation shall establish and maintain a comprehensive security governance framework that enc...
#
# 3. HYBRID (alpha=0.6):
# --------------------------------------------------------------------------------
# 1. 1.000 (D:1.00/S:1.00) | The organisation shall establish, document, and maintain a comprehensive risk management system cove...
# 2. 0.723 (D:0.89/S:0.47) | The organisation shall implement appropriate technical and organisational measures to address identi...
# 3. 0.424 (D:0.51/S:0.30) | The organisation shall implement continuous monitoring processes to track the effectiveness of risk ...
# CPU times: user 1.8 s, sys: 0 ns, total: 1.8 s
# Wall time: 634 ms

# %% [markdown]
# # Get subgraph around query results and visualise

# %% [markdown]
# ### Graph-Based Context Retrieval
#
# Get full context around relevant controls:
#
# ```python
# subgraph = get_subgraph_around_query("risk management", k=3, hops=1)
# ```
#
# **Returns:**
# - Relevant controls
# - Related topics and domains
# - All mapped standard references
# - Network connections

# %%
method_to_test = "hybrid"
possible_method_to_test = ["dense", "sparse", "hybrid"]
if not method_to_test in possible_method_to_test:
    raise ValueError(f"method_to_test has to be one of {possible_method_to_test}")

if method_to_test == "dense":
    # Dense search
    subgraph, results = get_subgraph_around_query(
        query="data privacy",
        G=G,
        search_func=dense_search,
        search_params={
            'node_vectors': node_vectors,
            'node_texts': node_texts,
            'model': model,
            'node_type': 'control'
        },
        k=3,
        hops=1
    )

elif method_to_test == "sparse":
    # Sparse search
    subgraph, results = get_subgraph_around_query(
        query="ISO27001 controls",
        G=G,
        search_func=sparse_search,
        search_params={
            'sparse_vectors': sparse_vectors,
            'sparse_vectorizer': sparse_vectorizer,
            'node_texts': node_texts,
            'node_type': 'control'
        },
        k=3,
        hops=1
    )

elif method_to_test == "hybrid":
    # Hybrid search
    subgraph, results = get_subgraph_around_query(
        query="risk management",
        G=G,
        search_func=hybrid_search,
        search_params={
            'node_vectors': node_vectors,
            'node_texts': node_texts,
            'sparse_vectors': sparse_vectors,
            'sparse_vectorizer': sparse_vectorizer,
            'model': model,
            'alpha': 0.7,
            'node_type': 'control'
        },
        k=3,
        hops=1
    )

# %%
print(f"Query: '{query}'")
print(f"Subgraph: {subgraph.number_of_nodes()} nodes, {subgraph.number_of_edges()} edges")

# Show what's in the subgraph
types_in_subgraph = {}
for node, data in subgraph.nodes(data=True):
    ntype = data.get('type', 'unknown')
    types_in_subgraph[ntype] = types_in_subgraph.get(ntype, 0) + 1

print("\nSubgraph composition:")
for ntype, count in types_in_subgraph.items():
    print(f"  {ntype}: {count}")
# Out:
# Query: 'data subject rights'
# Subgraph: 24 nodes, 21 edges
#
# Subgraph composition:
#   standard: 18
#   topic: 3
#   control: 3

# %% [markdown]
# # Visualization Capabilities

# %% [markdown]
# ## Interactive Visualization (PyVis)
#
# - Hover to see full control text
# - Click to explore connections
# - Physics-based layout
# - Filterable and zoomable
#
# **Features:**
# - Color legend for node types
# - Relevance-based sizing
# - Relationship labels on edges
# - Responsive browser-based interface

# %%
# With hybrid search
visualize_subgraph_interactive(
    query="data privacy protection",
    G=G,
    search_func=hybrid_search,
    search_params={
        'node_vectors': node_vectors,
        'node_texts': node_texts,
        'sparse_vectors': sparse_vectors,
        'sparse_vectorizer': sparse_vectorizer,
        'model': model,
        'alpha': 0.7,
        #'node_type': 'control'
    },
    k=4,
    hops=1,
    output_file='graph_hybrid.html'
)
# Out:
# ✓ Interactive graph saved to: graph_hybrid.html
#   Nodes: 13
#   Edges: 12
#         <iframe
#             width="100%"
#             height="750"
#             src="graph_hybrid.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Workflow v3 : do hybrid also for stage 2 (Node2Vec + semantic)

# %%
semantic_results, expanded, subgraph = search_and_expand_hybrid_filtered(
    query="data privacy protection",
    G=G,
    node_vectors=node_vectors,
    node_texts=node_texts,
    sparse_vectors=sparse_vectors,
    sparse_vectorizer=sparse_vectorizer,
    structural_vectors=structural_vectors,
    model=model,
    k_search=5,
    max_hops=10,
    min_structural_sim=0.5,   # Must be structurally similar
    min_semantic_sim=0.5,     # AND semantically relevant to query
    structural_weight=0.5,    # 50-50 balance
    alpha=0.7                 # Weight alpha to attribute to semantic (dense) search, (1 - alpha) for keyword (sparse) search
)

report = generate_report_hybrid_workflow_results(semantic_results, expanded)
print(report)
# Out:
# Stage 1: Hybrid search for 'data privacy protection'...
# --------------------------------------------------------------------------------
#
# Found 5 semantically relevant seed nodes:
#   1. control_30 (score: 0.981)
#      The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies...
#   2. control_27 (score: 0.870)
#      The organisation shall implement privacy by design principles in all AI systems, ensuring privacy co...
#   3. control_29 (score: 0.799)
#      The organisation shall establish processes to monitor compliance with privacy requirements, detect a...
#   4. control_19 (score: 0.526)
#      The organisation shall protect data throughout its lifecycle using appropriate technical and procedu...
#   5. control_28 (score: 0.498)
#      The organisation shall implement operational processes for the responsible collection, use, storage,...
#
# ================================================================================
# Stage 2: Hybrid filtering (structural + semantic)...
#   - Max hops: 10
#   - Min structural similarity: 0.5
#   - Min semantic similarity: 0.5
#   - Structural weight: 0.5
# --------------------------------------------------------------------------------
#
#   Expanding from: control_30
#   Found 2 neighbors (after hybrid filtering):
#     - domain_Privacy (predecessor, 2 hops)
#       Combined: 0.834 (Struct: 0.906, Sem: 0.761)
#     - topic_Privacy-Enhancing Technologies and Mechanisms (predecessor, 1 hops)
#       Combined: 0.830 (Struct: 0.986, Sem: 0.674)
#
#   Expanding from: control_27
#   Found 4 neighbors (after hybrid filtering):
#     - domain_Privacy (predecessor, 2 hops)
#       Combined: 0.835 (Struct: 0.908, Sem: 0.761)
#     - topic_Privacy by Design and Governance (predecessor, 1 hops)
#       Combined: 0.820 (Struct: 0.983, Sem: 0.656)
#     - std_SOC2_P1.1 P1.2 P1.3 (successor, 1 hops)
#       Combined: 0.788 (Struct: 0.950, Sem: 0.626)
#     - std_EU_AI_ACT_10.5 26.9 27.4 (successor, 1 hops)
#       Combined: 0.761 (Struct: 0.948, Sem: 0.574)
#
#   Expanding from: control_29
#   Found 2 neighbors (after hybrid filtering):
#     - domain_Privacy (predecessor, 2 hops)
#       Combined: 0.836 (Struct: 0.910, Sem: 0.761)
#     - topic_Privacy Compliance and Monitoring (predecessor, 1 hops)
#       Combined: 0.814 (Struct: 0.983, Sem: 0.646)
#
#   Expanding from: control_19
#   Found 1 neighbors (after hybrid filtering):
#     - topic_Data Security (predecessor, 1 hops)
#       Combined: 0.789 (Struct: 0.979, Sem: 0.599)
#
#   Expanding from: control_28
#   Found 2 neighbors (after hybrid filtering):
#     - domain_Privacy (predecessor, 2 hops)
#       Combined: 0.850 (Struct: 0.938, Sem: 0.761)
#     - topic_Personal Data Management (predecessor, 1 hops)
#       Combined: 0.817 (Struct: 0.984, Sem: 0.651)
#
# ================================================================================
# Building subgraph...
# ✓ Subgraph created:
#   Total nodes: 13
#   - Seed nodes: 5
#   - Found neighbors: 8
#   - Intermediate nodes: 0
#   Total edges: 11
# ================================================================================
# HYBRID-FILTERED WORKFLOW RESULTS
# ================================================================================
#
# 1. SEED NODE (Hybrid Search Match):
#    Node: control_30
#    Semantic Score: 0.981
#    Text: The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies in AI systems to protect personal data and ensure...
#    Domain: Privacy
#    Topic: Privacy-Enhancing Technologies and Mechanisms
#
#    HYBRID-FILTERED NEIGHBORS:
#    (Must pass BOTH structural AND semantic thresholds)
#    1. domain_Privacy (predecessor, 2 hops)
#       Combined: 0.834
#       └─ Structural: 0.906
#       └─ Semantic: 0.761
#       Type: domain
#       Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Managem...
#    2. topic_Privacy-Enhancing Technologies and Mechanisms (predecessor, 1 hops)
#       Combined: 0.830
#       └─ Structural: 0.986
#       └─ Semantic: 0.674
#       Type: topic
#       Topic: Privacy-Enhancing Technologies and Mechanisms. Domain: Privacy. Examples:...
#
# 2. SEED NODE (Hybrid Search Match):
#    Node: control_27
#    Semantic Score: 0.870
#    Text: The organisation shall implement privacy by design principles in all AI systems, ensuring privacy considerations are embedded from initial planning th...
#    Domain: Privacy
#    Topic: Privacy by Design and Governance
#
#    HYBRID-FILTERED NEIGHBORS:
#    (Must pass BOTH structural AND semantic thresholds)
#    1. domain_Privacy (predecessor, 2 hops)
#       Combined: 0.835
#       └─ Structural: 0.908
#       └─ Semantic: 0.761
#       Type: domain
#       Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Managem...
#    2. topic_Privacy by Design and Governance (predecessor, 1 hops)
#       Combined: 0.820
#       └─ Structural: 0.983
#       └─ Semantic: 0.656
#       Type: topic
#       Topic: Privacy by Design and Governance. Domain: Privacy. Examples: The organisa...
#    3. std_SOC2_P1.1 P1.2 P1.3 (successor, 1 hops)
#       Combined: 0.788
#       └─ Structural: 0.950
#       └─ Semantic: 0.626
#       Type: standard
#       SOC2 P1.1 P1.2 P1.3. Control: The organisation shall implement privacy by design...
#    4. std_EU_AI_ACT_10.5 26.9 27.4 (successor, 1 hops)
#       Combined: 0.761
#       └─ Structural: 0.948
#       └─ Semantic: 0.574
#       Type: standard
#       EU_AI_ACT 10.5 26.9 27.4. Control: The organisation shall implement privacy by d...
#
# 3. SEED NODE (Hybrid Search Match):
#    Node: control_29
#    Semantic Score: 0.799
#    Text: The organisation shall establish processes to monitor compliance with privacy requirements, detect and respond to privacy incidents, and ensure contin...
#    Domain: Privacy
#    Topic: Privacy Compliance and Monitoring
#
#    HYBRID-FILTERED NEIGHBORS:
#    (Must pass BOTH structural AND semantic thresholds)
#    1. domain_Privacy (predecessor, 2 hops)
#       Combined: 0.836
#       └─ Structural: 0.910
#       └─ Semantic: 0.761
#       Type: domain
#       Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Managem...
#    2. topic_Privacy Compliance and Monitoring (predecessor, 1 hops)
#       Combined: 0.814
#       └─ Structural: 0.983
#       └─ Semantic: 0.646
#       Type: topic
#       Topic: Privacy Compliance and Monitoring. Domain: Privacy. Examples: The organis...
#
# 4. SEED NODE (Hybrid Search Match):
#    Node: control_19
#    Semantic Score: 0.526
#    Text: The organisation shall protect data throughout its lifecycle using appropriate technical and procedural controls, including classification, encryption...
#    Domain: Security
#    Topic: Data Security
#
#    HYBRID-FILTERED NEIGHBORS:
#    (Must pass BOTH structural AND semantic thresholds)
#    1. topic_Data Security (predecessor, 1 hops)
#       Combined: 0.789
#       └─ Structural: 0.979
#       └─ Semantic: 0.599
#       Type: topic
#       Topic: Data Security. Domain: Security. Examples: The organisation shall protect...
#
# 5. SEED NODE (Hybrid Search Match):
#    Node: control_28
#    Semantic Score: 0.498
#    Text: The organisation shall implement operational processes for the responsible collection, use, storage, and disposal of personal data in AI systems. This...
#    Domain: Privacy
#    Topic: Personal Data Management
#
#    HYBRID-FILTERED NEIGHBORS:
#    (Must pass BOTH structural AND semantic thresholds)
#    1. domain_Privacy (predecessor, 2 hops)
#       Combined: 0.850
#       └─ Structural: 0.938
#       └─ Semantic: 0.761
#       Type: domain
#       Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Managem...
#    2. topic_Personal Data Management (predecessor, 1 hops)
#       Combined: 0.817
#       └─ Structural: 0.984
#       └─ Semantic: 0.651
#       Type: topic
#       Topic: Personal Data Management. Domain: Privacy. Examples: The organisation sha...

# %%
# Access subgraph data
print(f"\nSubgraph ({subgraph}) node attributes:")
for node in list(subgraph.nodes()):
    print(f"\n* {node}:")
    for key, value in subgraph.nodes[node].items():
        if key not in ['statement']:  # Skip long text
            print(f"  {key}: {value}")

# Export subgraph if needed
#nx.write_gml(subgraph, "filtered_subgraph.gml")

# Visualise subgraph
visualize_graph_with_pyvis(subgraph, output_file='hybrid_filtered_graph.html')
# Out:
# Subgraph (DiGraph with 13 nodes and 11 edges) node attributes:
#
# * std_EU_AI_ACT_10.5 26.9 27.4:
#   type: standard
#   standard: EU_AI_ACT
#   reference: 10.5 26.9 27.4
#   is_seed: False
#   seed_node: control_27
#   hop_distance: 1
#   direction: successor
#   structural_similarity: 0.9475840926170349
#   semantic_similarity: 0.5740383267402649
#   combined_score: 0.7608112096786499
#
# * topic_Data Security:
#   type: topic
#   name: Data Security
#   is_seed: False
#   seed_node: control_19
#   hop_distance: 1
#   direction: predecessor
#   structural_similarity: 0.9788761734962463
#   semantic_similarity: 0.5994614958763123
#   combined_score: 0.7891688346862793
#
# * control_28:
#   type: control
#   domain: Privacy
#   master: PR-2
#   topic: Personal Data Management
#   is_seed: True
#   seed_score: 0.49791723190820836
#   dense_score: 0.42099461863599436
#   sparse_score: 0.6774033295433743
#
# * control_30:
#   type: control
#   domain: Privacy
#   master: PR-4
#   topic: Privacy-Enhancing Technologies and Mechanisms
#   is_seed: True
#   seed_score: 0.9813581779242708
#   dense_score: 1.0
#   sparse_score: 0.9378605930809025
#
# * control_29:
#   type: control
#   domain: Privacy
#   master: PR-3
#   topic: Privacy Compliance and Monitoring
#   is_seed: True
#   seed_score: 0.7988539539478967
#   dense_score: 0.7823504152380664
#   sparse_score: 0.8373622109375007
#
# * domain_Privacy:
#   type: domain
#   name: Privacy
#   is_seed: False
#   seed_node: control_28
#   hop_distance: 2
#   direction: predecessor
#   structural_similarity: 0.9377665519714355
#   semantic_similarity: 0.7614507079124451
#   combined_score: 0.8496086597442627
#
# * topic_Personal Data Management:
#   type: topic
#   name: Personal Data Management
#   is_seed: False
#   seed_node: control_28
#   hop_distance: 1
#   direction: predecessor
#   structural_similarity: 0.983663022518158
#   semantic_similarity: 0.6509941816329956
#   combined_score: 0.8173285722732544
#
# * topic_Privacy Compliance and Monitoring:
#   type: topic
#   name: Privacy Compliance and Monitoring
#   is_seed: False
#   seed_node: control_29
#   hop_distance: 1
#   direction: predecessor
#   structural_similarity: 0.9827427864074707
#   semantic_similarity: 0.645642876625061
#   combined_score: 0.8141928315162659
#
# * control_27:
#   type: control
#   domain: Privacy
#   master: PR-1
#   topic: Privacy by Design and Governance
#   is_seed: True
#   seed_score: 0.8700921476827526
#   dense_score: 0.8144173538325037
#   sparse_score: 1.0
#
# * topic_Privacy-Enhancing Technologies and Mechanisms:
#   type: topic
#   name: Privacy-Enhancing Technologies and Mechanisms
#   is_seed: False
#   seed_node: control_30
#   hop_distance: 1
#   direction: predecessor
#   structural_similarity: 0.9855698943138123
#   semantic_similarity: 0.6742457151412964
#   combined_score: 0.8299077749252319
#
# * std_SOC2_P1.1 P1.2 P1.3:
#   type: standard
#   standard: SOC2
#   reference: P1.1 P1.2 P1.3
#   is_seed: False
#   seed_node: control_27
#   hop_distance: 1
#   direction: successor
#   structural_similarity: 0.9495089650154114
#   semantic_similarity: 0.6261639595031738
#   combined_score: 0.7878364324569702
#
# * topic_Privacy by Design and Governance:
#   type: topic
#   name: Privacy by Design and Governance
#   is_seed: False
#   seed_node: control_27
#   hop_distance: 1
#   direction: predecessor
#   structural_similarity: 0.9829707741737366
#   semantic_similarity: 0.6563557982444763
#   combined_score: 0.8196632862091064
#
# * control_19:
#   type: control
#   domain: Security
#   master: SE-4
#   topic: Data Security
#   is_seed: True
#   seed_score: 0.5258710458452406
#   dense_score: 0.5038435470554166
#   sparse_score: 0.5772685430214965
# ✓ Interactive graph saved to: hybrid_filtered_graph.html
#   Nodes: 13
#   Edges: 11
#         <iframe
#             width="100%"
#             height="750"
#             src="hybrid_filtered_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # LAST STEP : take exploration results and ask LLM to answer original client query only using subgraph

# %%
## Option 1: Natural language (most LLM-friendly)
#graph_text = graph_to_llm_context(subgraph, format='natural')
#
## Option 2: Markdown (good for structured analysis)
#graph_text = graph_to_llm_context(subgraph, format='markdown')
#
## Option 3: JSON (for programmatic LLMs)
#graph_text = graph_to_llm_context(subgraph, format='json')
#
## Option 4: Cypher (for graph database queries)
#graph_text = graph_to_llm_context(subgraph, format='cypher')

# Complete prompt
prompt = create_llm_prompt_with_graph(
    query="data privacy protection",
    subgraph=subgraph,
    report=report,
    format='natural'  # or 'markdown'
)

# Send to LLM
print(prompt)

# Save to file
with open('llm_prompt.txt', 'w') as f:
    f.write(prompt)
# Out:
# # Graph-Based Query Response
#
# ## User Query
# "data privacy protection"
#
# ## Search Results
# ================================================================================
# HYBRID-FILTERED WORKFLOW RESULTS
# ================================================================================
#
# 1. SEED NODE (Hybrid Search Match):
#    Node: control_30
#    Semantic Score: 0.981
#    Text: The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies in AI systems to protect personal data and ensure...
#    Domain: Privacy
#    Topic: Privacy-Enhancing Technologies and Mechanisms
#
#    HYBRID-FILTERED NEIGHBORS:
#    (Must pass BOTH structural AND semantic thresholds)
#    1. domain_Privacy (predecessor, 2 hops)
#       Combined: 0.834
#       └─ Structural: 0.906
#       └─ Semantic: 0.761
#       Type: domain
#       Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Managem...
#    2. topic_Privacy-Enhancing Technologies and Mechanisms (predecessor, 1 hops)
#       Combined: 0.830
#       └─ Structural: 0.986
#       └─ Semantic: 0.674
#       Type: topic
#       Topic: Privacy-Enhancing Technologies and Mechanisms. Domain: Privacy. Examples:...
#
# 2. SEED NODE (Hybrid Search Match):
#    Node: control_27
#    Semantic Score: 0.870
#    Text: The organisation shall implement privacy by design principles in all AI systems, ensuring privacy considerations are embedded from initial planning th...
#    Domain: Privacy
#    Topic: Privacy by Design and Governance
#
#    HYBRID-FILTERED NEIGHBORS:
#    (Must pass BOTH structural AND semantic thresholds)
#    1. domain_Privacy (predecessor, 2 hops)
#       Combined: 0.835
#       └─ Structural: 0.908
#       └─ Semantic: 0.761
#       Type: domain
#       Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Managem...
#    2. topic_Privacy by Design and Governance (predecessor, 1 hops)
#       Combined: 0.820
#       └─ Structural: 0.983
#       └─ Semantic: 0.656
#       Type: topic
#       Topic: Privacy by Design and Governance. Domain: Privacy. Examples: The organisa...
#    3. std_SOC2_P1.1 P1.2 P1.3 (successor, 1 hops)
#       Combined: 0.788
#       └─ Structural: 0.950
#       └─ Semantic: 0.626
#       Type: standard
#       SOC2 P1.1 P1.2 P1.3. Control: The organisation shall implement privacy by design...
#    4. std_EU_AI_ACT_10.5 26.9 27.4 (successor, 1 hops)
#       Combined: 0.761
#       └─ Structural: 0.948
#       └─ Semantic: 0.574
#       Type: standard
#       EU_AI_ACT 10.5 26.9 27.4. Control: The organisation shall implement privacy by d...
#
# 3. SEED NODE (Hybrid Search Match):
#    Node: control_29
#    Semantic Score: 0.799
#    Text: The organisation shall establish processes to monitor compliance with privacy requirements, detect and respond to privacy incidents, and ensure contin...
#    Domain: Privacy
#    Topic: Privacy Compliance and Monitoring
#
#    HYBRID-FILTERED NEIGHBORS:
#    (Must pass BOTH structural AND semantic thresholds)
#    1. domain_Privacy (predecessor, 2 hops)
#       Combined: 0.836
#       └─ Structural: 0.910
#       └─ Semantic: 0.761
#       Type: domain
#       Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Managem...
#    2. topic_Privacy Compliance and Monitoring (predecessor, 1 hops)
#       Combined: 0.814
#       └─ Structural: 0.983
#       └─ Semantic: 0.646
#       Type: topic
#       Topic: Privacy Compliance and Monitoring. Domain: Privacy. Examples: The organis...
#
# 4. SEED NODE (Hybrid Search Match):
#    Node: control_19
#    Semantic Score: 0.526
#    Text: The organisation shall protect data throughout its lifecycle using appropriate technical and procedural controls, including classification, encryption...
#    Domain: Security
#    Topic: Data Security
#
#    HYBRID-FILTERED NEIGHBORS:
#    (Must pass BOTH structural AND semantic thresholds)
#    1. topic_Data Security (predecessor, 1 hops)
#       Combined: 0.789
#       └─ Structural: 0.979
#       └─ Semantic: 0.599
#       Type: topic
#       Topic: Data Security. Domain: Security. Examples: The organisation shall protect...
#
# 5. SEED NODE (Hybrid Search Match):
#    Node: control_28
#    Semantic Score: 0.498
#    Text: The organisation shall implement operational processes for the responsible collection, use, storage, and disposal of personal data in AI systems. This...
#    Domain: Privacy
#    Topic: Personal Data Management
#
#    HYBRID-FILTERED NEIGHBORS:
#    (Must pass BOTH structural AND semantic thresholds)
#    1. domain_Privacy (predecessor, 2 hops)
#       Combined: 0.850
#       └─ Structural: 0.938
#       └─ Semantic: 0.761
#       Type: domain
#       Domain: Privacy. Topics: Privacy by Design and Governance, Personal Data Managem...
#    2. topic_Personal Data Management (predecessor, 1 hops)
#       Combined: 0.817
#       └─ Structural: 0.984
#       └─ Semantic: 0.651
#       Type: topic
#       Topic: Personal Data Management. Domain: Privacy. Examples: The organisation sha...
#
# ## Graph Structure
# This graph contains 13 nodes and 11 edges.
#
# Node types:
# - 2 standard node(s)
# - 5 topic node(s)
# - 5 control node(s)
# - 1 domain node(s)
#
# Nodes in the graph:
# - std_EU_AI_ACT_10.5 26.9 27.4 is a standard
# - topic_Data Security is a topic (name: 'Data Security')
# - control_28 is a control (statement: 'The organisation shall implement operational processes for the responsible collection, use, storage,')
# - control_30 is a control (statement: 'The organisation shall implement appropriate technical mechanisms and privacy-enhancing technologies')
# - control_29 is a control (statement: 'The organisation shall establish processes to monitor compliance with privacy requirements, detect a')
# - domain_Privacy is a domain (name: 'Privacy')
# - topic_Personal Data Management is a topic (name: 'Personal Data Management')
# - topic_Privacy Compliance and Monitoring is a topic (name: 'Privacy Compliance and Monitoring')
# - control_27 is a control (statement: 'The organisation shall implement privacy by design principles in all AI systems, ensuring privacy co')
# - topic_Privacy-Enhancing Technologies and Mechanisms is a topic (name: 'Privacy-Enhancing Technologies and Mechanisms')
# - std_SOC2_P1.1 P1.2 P1.3 is a standard
# - topic_Privacy by Design and Governance is a topic (name: 'Privacy by Design and Governance')
# - control_19 is a control (statement: 'The organisation shall protect data throughout its lifecycle using appropriate technical and procedu')
#
# Relationships:
# - topic_Data Security has_control control_19
# - domain_Privacy contains topic_Privacy by Design and Governance
# - domain_Privacy contains topic_Personal Data Management
# - domain_Privacy contains topic_Privacy Compliance and Monitoring
# - domain_Privacy contains topic_Privacy-Enhancing Technologies and Mechanisms
# - topic_Personal Data Management has_control control_28
# - topic_Privacy Compliance and Monitoring has_control control_29
# - control_27 maps_to std_EU_AI_ACT_10.5 26.9 27.4
# - control_27 maps_to std_SOC2_P1.1 P1.2 P1.3
# - topic_Privacy-Enhancing Technologies and Mechanisms has_control control_30
# - topic_Privacy by Design and Governance has_control control_27
#
# ## Task
# Based ONLY on the search results and graph structure provided above (ignore any external knowledge):
#
# 1. Answer the user's query using only the information present in the graph
# 2. Identify key nodes and relationships relevant to the query
# 3. Explain how different nodes are connected and what patterns emerge
# 4. Highlight any important information or insights from the subgraph
#
# IMPORTANT: Base your response exclusively on the provided graph data. Do not use external knowledge.

# %%
api_keys = {
    "Anthropic": os.getenv("ANTHROPIC_API_KEY"),
    "Mistral": os.getenv("MISTRAL_API_KEY"),
    "OpenAI": os.getenv("OPENAI_API_KEY"),
}

# %%
# %%time

#system_prompt = """
#Only base your response on the data provided.
#Do not add knowledge but describe it in a natural way as if you were a touristic guide, be friendly !
#You can add forms but not content.
#Format the output with nice Markdown format and emojis.
#"""
#
#prompt = f"""
#Here is the path I got from stations {start_station} to {end_station} : {df_path.to_dict()}.
#Describe the path between these two stations.
#Give me an itinerary of things I could visit on the way.
#"""

provider = "Anthropic"

result = query_llm(
    prompt=prompt,
    #system_prompt=system_prompt,
    provider=provider,
    api_key=api_keys[provider],
    temperature=0.2,
)
# Out:
# CPU times: user 187 ms, sys: 33.7 ms, total: 221 ms
# Wall time: 9.59 s

# %%
display(Markdown(result))
# Out:
# # Response to "data privacy protection"
#
# ## Key Insights from Graph Analysis
#
# ### Primary Findings
# The graph reveals a comprehensive approach to data privacy protection with multiple interconnected aspects:
#
# 1. Core Privacy Protection Mechanisms:
# - Privacy-Enhancing Technologies
# - Privacy by Design Principles
# - Personal Data Management
# - Privacy Compliance and Monitoring
#
# ### Relevant Nodes and Connections
#
# #### Key Control Nodes:
# 1. control_30: Implements technical mechanisms for privacy protection
#    - Focuses on privacy-enhancing technologies
#    - High semantic relevance (0.981)
#
# 2. control_27: Embeds privacy considerations from initial planning
#    - Implements "privacy by design" principles
#    - Semantic score of 0.870
#
# 3. control_29: Monitors privacy compliance
#    - Establishes processes to detect and respond to privacy incidents
#    - Semantic score of 0.799
#
# 4. control_28: Manages personal data lifecycle
#    - Covers collection, use, storage, and disposal of personal data
#    - Semantic score of 0.498
#
# #### Domain and Topic Connections:
# - All controls are connected to the domain_Privacy
# - Covers topics like:
#   - Privacy-Enhancing Technologies
#   - Privacy by Design
#   - Personal Data Management
#   - Privacy Compliance and Monitoring
#
# ### Standards Mapping
# - control_27 maps to two standards:
#   1. EU_AI_ACT (sections 10.5, 26.9, 27.4)
#   2. SOC2 (sections P1.1, P1.2, P1.3)
#
# ## Comprehensive Protection Strategy
# The graph illustrates a multi-layered approach to data privacy:
# 1. Proactive design (privacy by design)
# 2. Technical protection mechanisms
# 3. Operational data management
# 4. Continuous compliance monitoring
#
# ### Conclusion
# Data privacy protection involves technical, operational, and governance strategies that span the entire data lifecycle, with a focus on proactive protection and continuous monitoring.

# %% [markdown]
# TODO necessary:
# - plug LLM at the end for report : DONE
# - display subgraph : DONE
# - add graph creation using turingdb to show graph in visualiser
# - stage 1 find seed nodes using turingdb graph instead of networkx G (using node ID injection)
# - stage 2 exploration to do with turingdb queries instead of networkx G
# - biosearch v2 get subgraph with all pairwise entities paths
# - stage 2 add weight of if we are on a path between two seeds or not to know if the exploration makes sense
#
# TODO potential:
# - community detection
# - different levels of community
# - explanation of these communities

# %% [markdown]
# # Test : hypothetic document generation

# %% [markdown]
# # Test : after stage 1 ask LLM to say if seed node is relevant
